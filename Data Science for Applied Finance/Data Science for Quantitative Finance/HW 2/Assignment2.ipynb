# %% [markdown]
# # Assignment 2
# **Data Science for Quantitative Finance**
# **Bailey Griswold**
# **September 17, 2017**

# %% [markdown]
# Using BeautifulSoup scrape the state level for both parties and output the results in a df_results
# DataFrame indexed by
# - electiontype: one of ['Caucus', 'Primary']
# - state: state of the election
# - date: date at which the election took place
# - party: one of ['GOP', 'DEM']
#
# and containing the following columns
# - candidate: candidate name
# - votes: votes the candidate won
# - %votes: %votes the candidate won
# - delegates: delegates that candidate won

# %%
# import packages
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from fake_useragent import UserAgent

# %%
# website that contains all the state level primary election information
url = 'http://www.politico.com/mapdata-2016/2016-election/primary/results/map/president/'

# %%
# install fake-useragent https://pypi.python.org/pypi/fake-useragent

ua = UserAgent()

# %%
ua.chrome
# Out:
# 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2224.3 Safari/537.36'

# %%
header = {'User-Agent':str(ua.chrome)}
header
# Out:
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.17 (KHTML, like Gecko) Chrome/24.0.1312.60 Safari/537.17'}

# %%
# get the webpage using the fake-useragent header above
htmlContent = requests.get(url, headers=header)
htmlContent.text[:1000]
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7]><html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]><html class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]><html class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js"> <!--<![endif]-->\n\n<head>\n    <meta charset="utf-8" />\n    \n<link rel="stylesheet" type="text/css" href="http://static.politico.com/resource/assets/css/style-core.min.9aafe18e3e5e0097e2a0a0187d47818f.gz.css">\n<link rel="stylesheet" type="text/css" href="http://static.politico.com/resource/assets/css/style-election-2016.min.fe48e4432f8bf5e6002b91e519d2e55d.gz.css">\n<title>2016 Primary Election Results: President Live Map by State, Real-Time Voting Updates - POLITICO</title>\n<meta property="og:title" content="2016 Primary Election Results: President Live Map by State, Real-Time Voting Updates">\n<meta name="description" content="POLITICO&#39;s Live 2016 Primary Election Results and Maps by State, County and District. Includes 2016 Primary Races '

# %% [markdown]
# ### make a beautiful soup object of downloaded webpage content

# %%
# create a BeautifulSoup object that parses the html
soup = BeautifulSoup(htmlContent.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]><html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]><html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]><html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <link href="http://static.politico.com/resource/assets/css/style-core.min.9aafe18e3e5e0097e2a0a0187d47818f.gz.css" rel="stylesheet" type="text/css">
#    <link href="http://static.politico.com/resource/assets/css/style-election-2016.min.fe48e4432f8bf5e6002b91e519d2e55d.gz.css" rel="stylesheet" type="text/css">
#     <title>
#      2016 Primary Election Results: President Live Map by State, Real-Time Voting Updates - POLITICO
#     </title>
#     <meta content="2016 Primary Election Results: President Live Map by State, Real-Time Voting Updates" property="og:title">
#      <meta content="POLITICO's Live 2016 Primary Election Results and Maps by State, County and District. Includes 2016 Primary Races for President, Senate, House, Governor and Key Ballot Measures." name="description">
#       <meta content="POLITICO's Live 2016 Primary Election Results and Maps by State, County and District. Includes 2016 Primary Races for President, Senate, House, Governor and Key Ballot Measures." property="og:description">
#        <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#         <meta content="width=device-width, initial-scale=1" name="viewport">
#          <meta content="website" property="og:type">
#           <link href="http://www.politico.com/2016-election/primary/results/map/president" rel="canonical">
#            <meta content="http://www.politico.com/2016-election/primary/results/map/president" property="og:url">
#             <link href="http://static.politico.com/42/ce/c6868f924ceb87303ea77c2b41a4/election-hub.ico" rel="shortcut icon" type="image/x-icon">
#              <link href="http://static.politico.com/dims4/default/189063d/2147483647/legacy_thumbnail/144x144/quality/90/?url=http%3A%2F%2Fstatic.politico.com%2F42%2Fce%2Fc6868f924ceb87303ea77c2b41a4%2Felection-hub.ico" rel="apple-touch-icon-precomposed" sizes="144x144">
#               <link href="http://static.politico.com/dims4/default/55f1bd3/2147483647/legacy_thumbnail/114x114/quality/90/?url=http%3A%2F%2Fstatic.politico.com%2F42%2Fce%2Fc6868f924ceb87303ea77c2b41a4%2Felection-hub.ico" rel="apple-touch-icon-precomposed" sizes="114x114">
#                <link href="http://static.politico.com/dims4/default/e9b62d8/2147483647/legacy_thumbnail/72x72/quality/90/?url=http%3A%2F%2Fstatic.politico.com%2F42%2Fce%2Fc6868f924ceb87303ea77c2b41a4%2Felection-hub.ico" rel="apple-touch-icon-precomposed" sizes="72x72">
#                 <link href="http://static.politico.com/dims4/default/188e937/2147483647/legacy_thumbnail/57x57/quality/90/?url=http%3A%2F%2Fstatic.politico.com%2F42%2Fce%2Fc6868f924ceb87303ea77c2b41a4%2Felection-hub.ico" rel="apple-touch-icon-precomposed" sizes="57x57">
#                  <link href="/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60">
#                   <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72">
#                    <link href="/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76">
#                     <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114">
#                      <link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120">
#                       <link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144">
#                        <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152">
#                         <link href="/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180">
#                          <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png">
#                           <link href="/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png">
#                            <link href="/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png">
#                             <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png">
#                              <link href="/manifest.json" rel="manifest">
#                               <link color="#5bbad5" href="/safari-pinned-tab.svg" rel="mask-icon">
#                                <meta msapplication-tilecolor="content">
#                                 <meta msapplication-tileimage="content">
#                                  <meta theme-color="content">
#                                   <meta content="Election Hub" property="og:site_name">
#                                    <meta content="http://static.politico.com/af/ea/cb34e38c4780b4340927e63ab918/politico-2016.jpg.jpeg" property="og:image">
#                                     <meta content="www.politico.com" name="host">
#                                      <meta content="hotfix/emily 3b055de 2017-05-04T14:01:41Z" name="build">
#                                       <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js" type="text/javascript">
#                                       </script>
#                                       <script type="text/javascript">
#                                        window.jQuery || document.write('<script src="http://static.politico.com/resource/js/website/shared/libraries/jquery-1.11.0.min.daf47dbdebc0881066106b1dda1c9db3.gz.js"><\/script>')
#                                       </script>
#                                       <script src="http://static.politico.com/resource/js/website/shared/libraries/modernizr-2.8.3.min.eb9167fd3c12f05553135ffda5fcd108.gz.js" type="text/javascript">
#                                       </script>
#                                       <script src="http://static.politico.com/resource/assets/js.min/preload.62fed04045c8440c2240a494ad569fed.gz.js" type="text/javascript">
#                                       </script>
#                                       <script src="//tk.politico.com/zmr6qqx.js" type="text/javascript">
#                                       </script>
#                                       <script type="text/javascript">
#                                        try{Typekit.load();}catch(e){}
#                                       </script>
#                                      </meta>
#                                     </meta>
#                                    </meta>
#                                   </meta>
#                                  </meta>
#                                 </meta>
#                                </meta>
#                               </link>
#                              </link>
#                             </link>
#                            </link>
#                           </link>
#                          </link>
#                         </link>
#                        </link>
#                       </link>
#                      </link>
#                     </link>
#                    </link>
#                   </link>
#                  </link>
#                 </link>
#                </link>
#               </link>
#              </link>
#             </link>
#            </meta>
#           </link>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </link>
#   </link>
#  </head>
#  <body>
#   <script type="text/javascript">
#    var utag_data =
# {"organization_division":"anonymous","organization_uuid":"anonymous","organization_name":"anonymous","user_login_type":"anonymous","us_em":"anonymous","content_uuid":"00000151-ca4c-db97-a379-fa7e63620016/00000151-ca54-d2f3-a35d-ce5ffbaa0000","free_paid_content":"free","publication_date":"20151222","site_section":"elections","ad_unit_section":"elections","page_level_1":"2016-election","page_level_2":"primary","page_level_3":"results","page_level_4":"map","page_level_5":"president","page_type":"election results","site_domain":"www.politico.com","internal_site_id":"politico","page_name":"2016 Election:Results:Primary:President:Nation"};
#
# if (typeof(Storage) !== 'undefined') {
#  if (localStorage.uId !== undefined && localStorage.uId !== '') {
# utag_data["us_id"] = localStorage.uId;
# }
#  if (localStorage.uStatus !== undefined && localStorage.uStatus !== '') {
#  if (localStorage.uStatus === "logged in"){
# var statusCookieFound = false;
# var nameEQ = "uStatus=";
# var ca = document.cookie.split(';');
# for (var i = 0; i < ca.length; i++) {
#     var c = ca[i];
#     while (c.charAt(0) == ' ') c = c.substring(1, c.length);
#     if (c.indexOf(nameEQ) == 0) {
#         statusCookieFound = true;
#     }
# }
#
# if (!statusCookieFound) {
#     localStorage.uStatus = 'logged out';
# }
# }
# utag_data["us_st"] = localStorage.uStatus;} else {
# utag_data["us_st"] = "anonymous";
# }
#  if (localStorage.uCid !== undefined && localStorage.uCid !== '') {
# utag_data["us_co"] = localStorage.uCid;
# }
# }
# ;(function(a,b,c,d){
# a='//tags.tiqcdn.com/utag/politico/main/prod/utag.js';
# b=document;c='script';d=b.createElement(c);d.src=a;d.type='text/java'+c;d.async=true;
# a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);
# })();
#   </script>
#   <div class="global-wrapper sticky-wrapper" id="globalWrapper">
#    <!-- Need to include  sticky-wrapper -->
#    <div class="global-header" role="banner">
#     <div class="global-header-inner">
#      <div class="global-branding">
#       <h1>
#        <a href="http://www.politico.com/" target="_top" title="Home">
#         <b aria-hidden="true" class="icon icon-politico ">
#         </b>
#         <span class="icon-text">
#          ELECTION HUB
#         </span>
#        </a>
#       </h1>
#      </div>
#      <nav class="nav-micro" role="navigation">
#       <ul class="micro-list">
#        <li class="subnav micro-core-header-magazine-column conditional has-arrow format-s pos-alpha">
#         <div class="subnav-content">
#          <ul class="micro-sublist">
#           <li>
#            <a href="http://www.politico.com/magazine/" target="_top">
#             Magazine Home
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/magazine/" target="_blank">
#             Today's Cover
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/magazine/tag/opinion" target="_top">
#             Opinion
#            </a>
#           </li>
#           <li>
#            <a href="/magazine/#superLatest" target="_top">
#             Latest Stories
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/magazine/subscribe" target="_top">
#             Weekly Email Signups
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/magazine/what-works/" target="_top">
#             What Works
#            </a>
#           </li>
#          </ul>
#         </div>
#         <a class="subnav-toggle" href="http://www.politico.com/magazine/table-of-contents/2016/01" target="_blank">
#          Magazine
#         </a>
#         <div class="subnav-content">
#          <ul class="micro-sublist">
#           <li>
#            <a href="http://www.politico.com/magazine/" target="_top">
#             Magazine Home
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/magazine/" target="_blank">
#             Today's Cover
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/magazine/tag/opinion" target="_top">
#             Opinion
#            </a>
#           </li>
#           <li>
#            <a href="/magazine/#superLatest" target="_top">
#             Latest Stories
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/magazine/subscribe" target="_top">
#             Weekly Email Signups
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/magazine/what-works/" target="_top">
#             What Works
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#        <li class="subnav micro-core-header-policy-column conditional has-arrow format-s pos-alpha">
#         <div class="subnav-content">
#          <ul class="micro-sublist">
#           <li>
#            <a href="http://www.politico.com/agriculture" target="_top">
#             Agriculture
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/cybersecurity" target="_top">
#             Cybersecurity
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/defense" target="_top">
#             Defense
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/education" target="_top">
#             Education
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/ehealth" target="_top">
#             eHealth
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/energy-and-environment" target="_top">
#             Energy &amp; Environment
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/finance" target="_top">
#             Finance &amp; Tax
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/health-care" target="_top">
#             Health Care
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/tag/employment-immigration" target="_top">
#             Employment &amp; Immigration
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/technology" target="_top">
#             Technology
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/trade" target="_top">
#             Trade
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/transportation" target="_top">
#             Transportation &amp; Infrastructure
#            </a>
#           </li>
#          </ul>
#         </div>
#         <a class="subnav-toggle" href="#" target="_blank">
#          Policy
#         </a>
#         <div class="subnav-content">
#          <ul class="micro-sublist">
#           <li>
#            <a href="http://www.politico.com/agriculture" target="_top">
#             Agriculture
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/cybersecurity" target="_top">
#             Cybersecurity
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/defense" target="_top">
#             Defense
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/education" target="_top">
#             Education
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/ehealth" target="_top">
#             eHealth
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/energy-and-environment" target="_top">
#             Energy &amp; Environment
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/finance" target="_top">
#             Finance &amp; Tax
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/health-care" target="_top">
#             Health Care
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/tag/employment-immigration" target="_top">
#             Employment &amp; Immigration
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/technology" target="_top">
#             Technology
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/trade" target="_top">
#             Trade
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/transportation" target="_top">
#             Transportation &amp; Infrastructure
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#        <li class="subnav micro-core-header-pro-column format-s pos-alpha">
#         <a href="https://www.politicopro.com" target="_top">
#          <b aria-hidden="true" class="icon icon-pro-small-bold">
#          </b>
#          <span class="icon-text">
#           https://www.politicopro.com
#          </span>
#         </a>
#        </li>
#        <li class="subnav micro-core-header-search-link format-m pos-beta">
#         <a class="subnav-toggle" href="#" target="_blank">
#          <b aria-hidden="true" class="icon icon-search">
#          </b>
#          <span class="icon-text">
#           Search
#          </span>
#         </a>
#         <div class="subnav-content">
#          <form action="http://www.politico.com/search" class="simple-search" method="get">
#           <fieldset>
#            <input id="searchTerm" name="q" placeholder="" type="search"/>
#            <button class="button type-link" type="submit">
#             Search
#            </button>
#           </fieldset>
#          </form>
#         </div>
#        </li>
#        <li class="subnav micro-core-header-login-link format-s pos-beta">
#         <a class="subnav-toggle" href="#" target="_blank">
#          <b aria-hidden="true" class="icon icon-logged-in">
#          </b>
#          <span class="icon-text">
#           Login
#          </span>
#         </a>
#         <div class="subnav-content">
#          <ul class="micro-sublist">
#           <li>
#            <a href="https://secure.politico.com/settings" target="_top">
#             Account Details
#            </a>
#           </li>
#           <li>
#            <a class="politico-auth auth-log-in auth-logged-out " data-login="https://login.politico.com/_login?base=http%3A%2F%2Fwww.politico.com&amp;redirect=/_login&amp;logout=/_logout&amp;lRedirect=true&amp;sRedirect=" href="https://login.politico.com/_login?base=http%3A%2F%2Fwww.politico.com&amp;redirect=/_login&amp;logout=/_logout&amp;lRedirect=true&amp;sRedirect=&amp;js=false" style="display: none;" target="_blank">
#             Log In
#            </a>
#            <a class="politico-auth auth-log-out auth-logged-in" data-logout="https://login.politico.com/_logout?base=http%3A%2F%2Fwww.politico.com&amp;redirect=/_logout" href="https://login.politico.com/_logout?base=http%3A%2F%2Fwww.politico.com&amp;redirect=/_logout&amp;js=false" style="display: none;" target="_blank">
#             Log Out
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#        <li class="subnav micro-core-header-editions-dropdown has-arrow vary-text-visibility format-s pos-beta">
#         <a class="subnav-toggle" href="#" target="_blank">
#          <b aria-hidden="true" class="icon icon-globe">
#          </b>
#          <span class="icon-text">
#           U.S. Edition
#          </span>
#         </a>
#         <div class="subnav-content">
#          <ul class="micro-sublist">
#           <li>
#            <a href="http://www.politico.eu" target="_blank">
#             Europe Edition
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/media" target="_blank">
#             POLITICO Media
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/states/florida" target="_blank">
#             POLITICO Florida
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/states/new-jersey" target="_blank">
#             POLITICO New Jersey
#            </a>
#           </li>
#           <li>
#            <a href="http://www.politico.com/states/new-york" target="_blank">
#             POLITICO New York
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#       </ul>
#      </nav>
#      <nav class="nav-macro subnav" role="navigation">
#       <h5 class="subnav-toggle keyboard-accessible">
#        <b aria-hidden="true" class="icon icon-menu">
#        </b>
#        <span class="icon-text">
#         Menu
#        </span>
#       </h5>
#       <div class="subnav-content">
#        <div class="macro-row macro-verticals">
#         <div class="vertical-group capacity-small menu reveal-at-medium reveal-at-large reveal-at-extra">
#          <h6 class="menu-toggle keyboard-accessible">
#           Sections
#          </h6>
#          <ul class="vertical-list menu-content">
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/congress" target="_top">
#             Congress
#            </a>
#           </li>
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/white-house" target="_top">
#             White House
#            </a>
#           </li>
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/magazine/" target="_top">
#             Magazine
#            </a>
#           </li>
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/agenda/" target="_blank">
#             The Agenda
#            </a>
#           </li>
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/2016-election/results/map/president" target="_blank">
#             Latest Election Results
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="vertical-group capacity-small menu reveal-at-medium reveal-at-large reveal-at-extra">
#          <h6 class="menu-toggle keyboard-accessible">
#           POLITICO Live
#          </h6>
#          <ul class="vertical-list menu-content">
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/live-events" target="_blank">
#             POLITICO Live Home
#            </a>
#           </li>
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/live-events/upcoming" target="_blank">
#             Upcoming Events
#            </a>
#           </li>
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/live-events/previous" target="_blank">
#             Previous Events
#            </a>
#           </li>
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/live-events/about" target="_blank">
#             About POLITICO Live
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="vertical-group capacity-small menu reveal-at-medium reveal-at-large reveal-at-extra">
#          <h6 class="menu-toggle keyboard-accessible">
#           Multimedia
#          </h6>
#          <ul class="vertical-list menu-content">
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/video" target="_top">
#             All Video
#            </a>
#           </li>
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/podcasts" target="_blank">
#             POLITICO Podcasts
#            </a>
#           </li>
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/news/playback" target="_top">
#             Playback
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="vertical-group capacity-small menu reveal-at-medium reveal-at-large reveal-at-extra">
#          <h6 class="menu-toggle keyboard-accessible">
#           Blogs &amp; Columns
#          </h6>
#          <ul class="vertical-list menu-content">
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/playbook-plus" target="_top">
#             Playbook Plus
#            </a>
#           </li>
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/news/simon-says" target="_top">
#             Roger Simon
#            </a>
#           </li>
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/blogs/media" target="_top">
#             On Media
#            </a>
#           </li>
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/blogs/under-the-radar" target="_top">
#             Josh Gerstein
#            </a>
#           </li>
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/magazine/tag/rich-lowry" target="_blank">
#             Rich Lowry
#            </a>
#           </li>
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/blogs/donald-trump-administration" target="_blank">
#             45 Presidential Tracker
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="vertical-group capacity-small menu reveal-at-medium reveal-at-large reveal-at-extra">
#          <h6 class="menu-toggle keyboard-accessible">
#           Series
#          </h6>
#          <ul class="vertical-list menu-content">
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/magazine/what-works/" target="_top">
#             What Works
#            </a>
#           </li>
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/WomenRule" target="_top">
#             Women Rule
#            </a>
#           </li>
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/caucus" target="_blank">
#             POLITICO Caucus
#            </a>
#           </li>
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/agenda/issue/agenda-2020-november-2016" target="_blank">
#             Agenda 2020
#            </a>
#           </li>
#           <li>
#            <!-- leaving otherwise block so it can fall to somewhere -->
#            <a href="http://www.politico.com/agenda/issue/100-days-trade" target="_blank">
#             The First 100 Days: Trade
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="vertical-group capacity-small menu reveal-at-medium reveal-at-large reveal-at-extra">
#          <h6 class="menu-toggle">
#           Connect With Us
#          </h6>
#          <ul class="vertical-follow menu-content">
#          </ul>
#         </div>
#        </div>
#       </div>
#      </nav>
#     </div>
#    </div>
#    <header class="local-header sticky-content">
#     <div class="local-header-inner">
#      <nav class="local-nav">
#       <ul class="secondary-nav pos-alpha" role="navigation">
#        <li class="nav-historical is-emphasized subnav">
#         <a class="subnav-toggle" href="javascript:void(0);">
#          2016 Election Results
#          <b aria-hidden="true" class="icon icon-down">
#          </b>
#         </a>
#         <div class="subnav-content">
#          <ul class="tertiary-nav">
#           <li class="nav-2016-results ">
#            <ul class="quaternery-nav">
#             <li class="current">
#              <a href="http://www.politico.com/2016-election/results/map/president">
#               Election Results
#              </a>
#             </li>
#             <li>
#              <a href="http://www.politico.com/2016-election/results/delegate-count-tracker">
#               Delegate Tracker
#              </a>
#             </li>
#             <li>
#              <a href="http://www.politico.com/2016-election/polls/">
#               Polling Center
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="nav-2014-results">
#            <a href="http://www.politico.com/2014-election/general/results/map/senate/" target="_top">
#             2014 Elections
#            </a>
#           </li>
#           <li class="nav-2012-results">
#            <a href="http://www.politico.com/2012-election/results/map/#/President/2012/" target="_top">
#             2012 Elections
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#       </ul>
#       <ul class="secondary-nav pos-alpha priority-nav" role="navigation">
#        <li class="nav-more-races subnav is-flipped priority-parent">
#         <a class="subnav-toggle" href="#">
#          <b aria-hidden="true" class="icon icon-flag">
#          </b>
#          <span class="icon-text">
#           More Races
#          </span>
#         </a>
#         <div class="subnav-content">
#          <ul class="tertiary-nav priority-origin">
#           <li class="nav-president-general priority-item current" data-cloned-group="President" data-reveal-at="450">
#            <a href="http://www.politico.com/2016-election/results/map/president" target="_top">
#             Presidential General Elections
#            </a>
#           </li>
#           <li class="nav-president-primary priority-item" data-cloned-group="President" data-reveal-at="450">
#            <a href="http://www.politico.com/2016-election/primary/results/map/president" target="_top">
#             Presidential Primary Elections
#            </a>
#           </li>
#           <li class="nav-senate-general priority-item " data-cloned-group="Senate" data-reveal-at="450">
#            <a href="http://www.politico.com/2016-election/results/map/senate" target="_top">
#             Senate General Elections
#            </a>
#           </li>
#           <li class="nav-senate-primary priority-item" data-cloned-group="Senate" data-reveal-at="450">
#            <a href="http://www.politico.com/2016-election/primary/results/map/senate" target="_top">
#             Senate Primary Elections
#            </a>
#           </li>
#           <li class="nav-house-general priority-item " data-cloned-group="House" data-reveal-at="512">
#            <a href="http://www.politico.com/2016-election/results/map/house" target="_top">
#             House General Elections
#            </a>
#           </li>
#           <li class="nav-house-primary priority-item" data-cloned-group="House" data-reveal-at="512">
#            <a href="http://www.politico.com/2016-election/primary/results/map/house" target="_top">
#             House Primary Elections
#            </a>
#           </li>
#           <li class="nav-governor-general priority-item " data-cloned-group="Governor" data-reveal-at="740">
#            <a href="http://www.politico.com/2016-election/results/map/governor" target="_top">
#             Governor General Elections
#            </a>
#           </li>
#           <li class="nav-governor-primary priority-item" data-cloned-group="Governor" data-reveal-at="740">
#            <a href="http://www.politico.com/2016-election/primary/results/map/governor" target="_top">
#             Governor Primary Elections
#            </a>
#           </li>
#           <li class="nav-ballot priority-item " data-reveal-at="1136">
#            <a href="http://www.politico.com/2016-election/results/map/ballot-measures" target="_top">
#             Ballot Measures
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#       </ul>
#       <ul class="secondary-nav pos-alpha">
#        <li class="nav-state subnav is-flipped format-wide ">
#         <a class="subnav-toggle" href="#">
#          <b aria-hidden="true" class="icon icon-pin">
#          </b>
#          <span class="icon-text">
#           State
#          </span>
#         </a>
#         <div class="subnav-content">
#          <div class="all-states">
#           <div class="all-states-list" data-make-select="">
#            <ol>
#             <li>
#              <a data-opt-group="A" href="http://www.politico.com/2016-election/results/alabama/">
#               <b aria-hidden="true" class="stateface stateface-al">
#               </b>
#               Alabama
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="A" href="http://www.politico.com/2016-election/results/alaska/">
#               <b aria-hidden="true" class="stateface stateface-ak">
#               </b>
#               Alaska
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="A" href="http://www.politico.com/2016-election/results/arizona/">
#               <b aria-hidden="true" class="stateface stateface-az">
#               </b>
#               Arizona
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="A" href="http://www.politico.com/2016-election/results/arkansas/">
#               <b aria-hidden="true" class="stateface stateface-ar">
#               </b>
#               Arkansas
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="C" href="http://www.politico.com/2016-election/results/california/">
#               <b aria-hidden="true" class="stateface stateface-ca">
#               </b>
#               California
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="C" href="http://www.politico.com/2016-election/results/colorado/">
#               <b aria-hidden="true" class="stateface stateface-co">
#               </b>
#               Colorado
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="C" href="http://www.politico.com/2016-election/results/connecticut/">
#               <b aria-hidden="true" class="stateface stateface-ct">
#               </b>
#               Connecticut
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="D" href="http://www.politico.com/2016-election/results/delaware/">
#               <b aria-hidden="true" class="stateface stateface-de">
#               </b>
#               Delaware
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="D" href="http://www.politico.com/2016-election/results/district-of-columbia/">
#               <b aria-hidden="true" class="stateface stateface-dc">
#               </b>
#               District of Columbia
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="F" href="http://www.politico.com/2016-election/results/florida/">
#               <b aria-hidden="true" class="stateface stateface-fl">
#               </b>
#               Florida
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="G" href="http://www.politico.com/2016-election/results/georgia/">
#               <b aria-hidden="true" class="stateface stateface-ga">
#               </b>
#               Georgia
#              </a>
#             </li>
#            </ol>
#            <ol>
#             <li>
#              <a data-opt-group="H" href="http://www.politico.com/2016-election/results/hawaii/">
#               <b aria-hidden="true" class="stateface stateface-hi">
#               </b>
#               Hawaii
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="I" href="http://www.politico.com/2016-election/results/idaho/">
#               <b aria-hidden="true" class="stateface stateface-id">
#               </b>
#               Idaho
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="I" href="http://www.politico.com/2016-election/results/illinois/">
#               <b aria-hidden="true" class="stateface stateface-il">
#               </b>
#               Illinois
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="I" href="http://www.politico.com/2016-election/results/indiana/">
#               <b aria-hidden="true" class="stateface stateface-in">
#               </b>
#               Indiana
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="I" href="http://www.politico.com/2016-election/results/iowa/">
#               <b aria-hidden="true" class="stateface stateface-ia">
#               </b>
#               Iowa
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="K" href="http://www.politico.com/2016-election/results/kansas/">
#               <b aria-hidden="true" class="stateface stateface-ks">
#               </b>
#               Kansas
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="K" href="http://www.politico.com/2016-election/results/kentucky/">
#               <b aria-hidden="true" class="stateface stateface-ky">
#               </b>
#               Kentucky
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="L" href="http://www.politico.com/2016-election/results/louisiana/">
#               <b aria-hidden="true" class="stateface stateface-la">
#               </b>
#               Louisiana
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="M" href="http://www.politico.com/2016-election/results/maine/">
#               <b aria-hidden="true" class="stateface stateface-me">
#               </b>
#               Maine
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="M" href="http://www.politico.com/2016-election/results/maryland/">
#               <b aria-hidden="true" class="stateface stateface-md">
#               </b>
#               Maryland
#              </a>
#             </li>
#            </ol>
#            <ol>
#             <li>
#              <a data-opt-group="M" href="http://www.politico.com/2016-election/results/massachusetts/">
#               <b aria-hidden="true" class="stateface stateface-ma">
#               </b>
#               Massachusetts
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="M" href="http://www.politico.com/2016-election/results/michigan/">
#               <b aria-hidden="true" class="stateface stateface-mi">
#               </b>
#               Michigan
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="M" href="http://www.politico.com/2016-election/results/minnesota/">
#               <b aria-hidden="true" class="stateface stateface-mn">
#               </b>
#               Minnesota
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="M" href="http://www.politico.com/2016-election/results/mississippi/">
#               <b aria-hidden="true" class="stateface stateface-ms">
#               </b>
#               Mississippi
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="M" href="http://www.politico.com/2016-election/results/missouri/">
#               <b aria-hidden="true" class="stateface stateface-mo">
#               </b>
#               Missouri
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="M" href="http://www.politico.com/2016-election/results/montana/">
#               <b aria-hidden="true" class="stateface stateface-mt">
#               </b>
#               Montana
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="N" href="http://www.politico.com/2016-election/results/nebraska/">
#               <b aria-hidden="true" class="stateface stateface-ne">
#               </b>
#               Nebraska
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="N" href="http://www.politico.com/2016-election/results/nevada/">
#               <b aria-hidden="true" class="stateface stateface-nv">
#               </b>
#               Nevada
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="N" href="http://www.politico.com/2016-election/results/new-hampshire/">
#               <b aria-hidden="true" class="stateface stateface-nh">
#               </b>
#               New Hampshire
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="N" href="http://www.politico.com/2016-election/results/new-jersey/">
#               <b aria-hidden="true" class="stateface stateface-nj">
#               </b>
#               New Jersey
#              </a>
#             </li>
#            </ol>
#            <ol>
#             <li>
#              <a data-opt-group="N" href="http://www.politico.com/2016-election/results/new-mexico/">
#               <b aria-hidden="true" class="stateface stateface-nm">
#               </b>
#               New Mexico
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="N" href="http://www.politico.com/2016-election/results/new-york/">
#               <b aria-hidden="true" class="stateface stateface-ny">
#               </b>
#               New York
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="N" href="http://www.politico.com/2016-election/results/north-carolina/">
#               <b aria-hidden="true" class="stateface stateface-nc">
#               </b>
#               North Carolina
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="N" href="http://www.politico.com/2016-election/results/north-dakota/">
#               <b aria-hidden="true" class="stateface stateface-nd">
#               </b>
#               North Dakota
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="O" href="http://www.politico.com/2016-election/results/ohio/">
#               <b aria-hidden="true" class="stateface stateface-oh">
#               </b>
#               Ohio
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="O" href="http://www.politico.com/2016-election/results/oklahoma/">
#               <b aria-hidden="true" class="stateface stateface-ok">
#               </b>
#               Oklahoma
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="O" href="http://www.politico.com/2016-election/results/oregon/">
#               <b aria-hidden="true" class="stateface stateface-or">
#               </b>
#               Oregon
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="P" href="http://www.politico.com/2016-election/results/pennsylvania/">
#               <b aria-hidden="true" class="stateface stateface-pa">
#               </b>
#               Pennsylvania
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="R" href="http://www.politico.com/2016-election/results/rhode-island/">
#               <b aria-hidden="true" class="stateface stateface-ri">
#               </b>
#               Rhode Island
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="S" href="http://www.politico.com/2016-election/results/south-carolina/">
#               <b aria-hidden="true" class="stateface stateface-sc">
#               </b>
#               South Carolina
#              </a>
#             </li>
#            </ol>
#            <ol>
#             <li>
#              <a data-opt-group="S" href="http://www.politico.com/2016-election/results/south-dakota/">
#               <b aria-hidden="true" class="stateface stateface-sd">
#               </b>
#               South Dakota
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="T" href="http://www.politico.com/2016-election/results/tennessee/">
#               <b aria-hidden="true" class="stateface stateface-tn">
#               </b>
#               Tennessee
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="T" href="http://www.politico.com/2016-election/results/texas/">
#               <b aria-hidden="true" class="stateface stateface-tx">
#               </b>
#               Texas
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="U" href="http://www.politico.com/2016-election/results/utah/">
#               <b aria-hidden="true" class="stateface stateface-ut">
#               </b>
#               Utah
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="V" href="http://www.politico.com/2016-election/results/vermont/">
#               <b aria-hidden="true" class="stateface stateface-vt">
#               </b>
#               Vermont
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="V" href="http://www.politico.com/2016-election/results/virginia/">
#               <b aria-hidden="true" class="stateface stateface-va">
#               </b>
#               Virginia
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="W" href="http://www.politico.com/2016-election/results/washington/">
#               <b aria-hidden="true" class="stateface stateface-wa">
#               </b>
#               Washington
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="W" href="http://www.politico.com/2016-election/results/west-virginia/">
#               <b aria-hidden="true" class="stateface stateface-wv">
#               </b>
#               West Virginia
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="W" href="http://www.politico.com/2016-election/results/wisconsin/">
#               <b aria-hidden="true" class="stateface stateface-wi">
#               </b>
#               Wisconsin
#              </a>
#             </li>
#             <li>
#              <a data-opt-group="W" href="http://www.politico.com/2016-election/results/wyoming/">
#               <b aria-hidden="true" class="stateface stateface-wy">
#               </b>
#               Wyoming
#              </a>
#             </li>
#            </ol>
#           </div>
#          </div>
#         </div>
#        </li>
#       </ul>
#       <ul class="secondary-nav pos-beta" role="navigation">
#        <li class="nav-schedule ">
#         <a href="http://www.politico.com/2016-election/schedule" target="_top">
#          <b aria-hidden="true" class="icon icon-calendar">
#          </b>
#          <span class="icon-text">
#           Schedule
#          </span>
#         </a>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </header>
#    <script>
#     window.serverDate = '20170504';
#     window.isLive = false;
#     window.liveDate = '';
#    </script>
#    <div class="super-duper">
#     <div class="super elections-top">
#      <div class="super-inner">
#       <div class="content layout-full">
#        <section class="content-groupset pos-omega">
#         <div class="content-group ad ">
#          <div class="ad-slot flex horizontal " id="pol-01">
#          </div>
#         </div>
#        </section>
#       </div>
#      </div>
#     </div>
#     <div class="super no-border" role="main">
#      <div class="super-inner">
#       <div class="election-content election-results layout-full">
#        <section class="content-group election-intro">
#         <footer class="content-meta">
#          <div class="meta-group meta-context">
#           <dl class="updated">
#            <dt>
#             Updated:
#            </dt>
#            <dd>
#             4/18/16 3:22:25 PM EDT
#            </dd>
#           </dl>
#           <dl class="source">
#            <dt>
#             Source:
#            </dt>
#            <b>
#             AP
#            </b>
#           </dl>
#          </div>
#          <div class="meta-group meta-share">
#           <ul class="share-list" data-share-loaded="true" data-share-url="http://www.politico.com/2016-election/primary/results/map/president">
#            <li class="share-facebook">
#             <a href="http://api.addthis.com/oexchange/0.8/forward/facebook/offer?pco=tbx32nj-1.0&amp;url=http://www.politico.com/2016-election/primary/results/map/president&amp;pubid=politico.com" target="_blank">
#              <b aria-hidden="true" class="icon icon-facebook">
#              </b>
#              <span class="count-facebook" style="opacity: 1;">
#               Facebook
#              </span>
#             </a>
#            </li>
#            <li class="share-twitter">
#             <a href="http://api.addthis.com/oexchange/0.8/forward/twitter/offer?pco=tbx32nj-1.0&amp;url=http://www.politico.com/2016-election/primary/results/map/president&amp;hashtags=election2014&amp;text=2016 Presidential Primaries Results &amp;pubid=politico.com" target="_blank">
#              <b aria-hidden="true" class="icon icon-twitter">
#              </b>
#              <span class="count-twitter">
#               Twitter
#              </span>
#             </a>
#            </li>
#            <li class="share-google-plus">
# ...
#               <div class="text-key">
#                <dl>
#                 <dt>
#                  *
#                 </dt>
#                 <dd>
#                  Runoff
#                 </dd>
#                </dl>
#               </div>
#              </div>
#              <p class="fs-12">
#              </p>
#             </footer>
#            </article>
#           </li>
#          </ol>
#         </article>
#        </section>
#       </div>
#       <div class="content-beta sticky-content">
#        <div class="super contrast-skin elections-sticky-right">
#         <div class="super-inner">
#          <div class="content layout-full">
#           <section class="content-groupset pos-omega">
#            <div class="content-group ad ">
#             <div class="ad-slot flex vertical " id="pol-02">
#             </div>
#            </div>
#           </section>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="global-footer" role="contentinfo">
#     <div class="global-footer-inner">
#      <div class="footer-group footer-intro">
#       <div class="footer-branding">
#        <h2>
#         <a href="http://www.politico.com/" target="_top" title="Home">
#          <b aria-hidden="true" class="icon icon-politico">
#          </b>
#          <span class="icon-text">
#           More on Election Hub
#          </span>
#         </a>
#        </h2>
#       </div>
#       <div class="footer-actions">
#        <form class="simple-nav orient-horizontal color-inverted">
#         <fieldset>
#          <label for="jumpEdition">
#           <b aria-hidden="true" class="icon icon-globe">
#           </b>
#           <span class="icon-text">
#            Core Footer - dropdown links
#           </span>
#          </label>
#          <select id="jumpEdition" name="jumpEdition">
#           <option selected="selected" value="">
#            U.S. Edition
#           </option>
#           <option value="http://www.politico.eu/">
#            Europe Edition
#           </option>
#          </select>
#         </fieldset>
#        </form>
#       </div>
#      </div>
#      <div class="footer-group footer-nav">
#       <div class="menu with-hidden-toggle reveal-at-large reveal-at-extra">
#        <h5 class="menu-toggle">
#         Election Hub Links
#        </h5>
#        <div class="menu-content">
#         <div class="additional-links">
#          <nav class="additional-nav" role="navigation">
#           <h6>
#            News
#           </h6>
#           <ul>
#            <li>
#             <a href="http://www.politico.com/" target="_top">
#              POLITICO Home
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/magazine/" target="_top">
#              Magazine
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/2016-election/results/map/president" target="_blank">
#              2016 Elections
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/congress" target="_top">
#              Congress
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/video" target="_top">
#              Video
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/podcasts" target="_blank">
#              Podcasts
#             </a>
#            </li>
#            <li>
#             <a href="https://www.politicopro.com/" target="_top">
#              POLITICO Pro
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/media" target="_blank">
#              POLITICO Media
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/states/florida" target="_blank">
#              POLITICO Florida
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/states/new-jersey" target="_blank">
#              POLITICO New Jersey
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/states/new-york" target="_blank">
#              POLITICO New York
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/live-events" target="_top">
#              POLITICO Live
#             </a>
#            </li>
#           </ul>
#          </nav>
#          <nav class="additional-nav" role="navigation">
#           <h6>
#            Blogs, Columns &amp; Cartoons
#           </h6>
#           <ul>
#            <li>
#             <a href="http://www.politico.com/magazine/tag/fourth-estate" target="_blank">
#              Jack Shafer
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/blogs/media" target="_top">
#              On Media
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/blogs/under-the-radar" target="_top">
#              Josh Gerstein
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/news/matt-wuerker" target="_blank">
#              Matt Wuerker
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/magazine/tag/rich-lowry" target="_blank">
#              Rich Lowry
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tag/cartoon-carousel" target="_blank">
#              Cartoon Carousel
#             </a>
#            </li>
#           </ul>
#          </nav>
#          <nav class="additional-nav" role="navigation">
#           <h6>
#            Tipsheets
#           </h6>
#           <ul>
#            <li>
#             <a href="http://www.politico.com/tipsheets/the-2016-blast" target="_top">
#              The 2016 Blast
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/playbook" target="_top">
#              Playbook
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tipsheets/huddle" target="_top">
#              Huddle
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/magazine/newsletter" target="_top">
#              The Friday Cover
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tipsheets/politico-influence" target="_top">
#              Influence
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tipsheets/morning-agriculture" target="_top">
#              Morning Agriculture
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tipsheets/morning-cybersecurity" target="_top">
#              Morning Cybersecurity
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tipsheets/morning-defense" target="_top">
#              Morning Defense
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tipsheets/morning-education" target="_top">
#              Morning Education
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tipsheets/morning-ehealth" target="_top">
#              Morning eHealth
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tipsheets/morning-energy" target="_top">
#              Morning Energy
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tipsheets/morning-money" target="_top">
#              Morning Money
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tipsheets/morning-score" target="_top">
#              Morning Score
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tipsheets/morning-shift" target="_top">
#              Morning Shift
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tipsheets/morning-tax" target="_top">
#              Morning Tax
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tipsheets/morning-tech" target="_top">
#              Morning Tech
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tipsheets/morning-trade" target="_top">
#              Morning Trade
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tipsheets/morning-transportation" target="_top">
#              Morning Transportation
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tipsheets/politico-pulse" target="_top">
#              Pulse
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tipsheets/prescription-pulse" target="_top">
#              Prescription Pulse
#             </a>
#            </li>
#           </ul>
#          </nav>
#          <nav class="additional-nav" role="navigation">
#           <h6>
#            Policy
#           </h6>
#           <ul>
#            <li>
#             <a href="http://www.politico.com/agriculture" target="_top">
#              Agriculture
#             </a>
#            </li>
#            <li>
#             <a href="https://www.politicopro.com/campaigns" target="_top">
#              Campaigns
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/cybersecurity" target="_top">
#              Cybersecurity
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/defense" target="_top">
#              Defense
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/education" target="_top">
#              Education
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/ehealth" target="_top">
#              eHealth
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/energy-and-environment" target="_top">
#              Energy &amp; Environment
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/finance" target="_top">
#              Finance &amp; Tax
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/health-care" target="_top">
#              Health Care
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/tag/employment-immigration" target="_top">
#              Employment &amp; Immigration
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/technology" target="_top">
#              Technology
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/trade" target="_top">
#              Trade
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/transportation" target="_top">
#              Transportation &amp; Infrastructure
#             </a>
#            </li>
#           </ul>
#          </nav>
#          <nav class="additional-nav double" role="navigation">
#           <h6>
#            More Info
#           </h6>
#           <ul class="first">
#            <li>
#             <a href="http://www.politico.com/about/" target="_top">
#              About Us
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/about/advertising" target="_top">
#              Advertising
#             </a>
#            </li>
#            <li>
#             Breaking News Alerts
#            </li>
#            <li>
#             <a href="https://secure.politico.com/payment" target="_blank">
#              Credit Card Payments
#             </a>
#            </li>
#            <li>
#             <a href="http://edition.pagesuite-professional.co.uk/Launch.aspx?bypass=true&amp;PBID=74262970-aa07-44b3-80c8-21fa8a8ac376" target="_blank">
#              Digital Edition
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/employment" target="_top">
#              Employment
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/faq" target="_top">
#              FAQ
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/feedback" target="_top">
#              Feedback
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/politics" target="_top">
#              Headlines
#             </a>
#            </li>
#           </ul>
#           <ul class="last">
#            <li>
#             <a href="http://www.politico.com/gallery" target="_top">
#              Photos
#             </a>
#            </li>
#            <li>
#             <a href="http://www.powerjobs.com/" target="_blank">
#              POWERJobs
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/about/other-brands/politico-states/press" target="_top">
#              Press
#             </a>
#            </li>
#            <li>
#             Register
#            </li>
#            <li>
#             <a href="http://www.politico.com/subscriptions" target="_blank">
#              Print Subscriptions
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/rss" target="_top">
#              RSS/Widgets
#             </a>
#            </li>
#            <li>
#             <a href="http://www.politico.com/sitemap" target="_top">
#              Site Map
#             </a>
#            </li>
#            <li>
#             <a href="http://www.cafepress.com/thepolitico" target="_blank">
#              Store
#             </a>
#            </li>
#           </ul>
#          </nav>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="footer-group footer-legal">
#       <p class="copyright">
#        © 2017 POLITICO LLC
#       </p>
#       <ul class="legal-links">
#        <li>
#         <a href="http://www.politico.com/terms-of-service" target="_top">
#          Terms of Service
#         </a>
#        </li>
#        <li>
#         <a href="http://www.politico.com/privacy-policy" target="_top">
#          Privacy Policy
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#    <script>
#     var gptadslots=[];
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function(){
#   var gads = document.createElement('script');
#   gads.async = true;
#   gads.type = 'text/javascript';
#   var useSSL = 'https:' == document.location.protocol;
#   gads.src = (useSSL ? 'https:' : 'http:') + '//www.googletagservices.com/tag/js/gpt.js';
#   var node = document.getElementsByTagName('script')[0];
#   node.parentNode.insertBefore(gads, node);
# })();
#    </script>
#    <script src="http://static.politico.com/resource/assets/js.min/scriptloader.cab00b3c1625d35a5b7d14e319312771.gz.js" type="text/javascript">
#    </script>
#    <script>
#     var scripts = [{'inline': function() { if (Modernizr.touch) { document.write('<script src="http://static.politico.com/resource/js/website/shared/libraries/jquery-mobile-1.4.5.min.483cba40ca58d0ada0632d01953d42f4.gz.js"><\/script>'); } } },{'src': 'http://static.politico.com/resource/js/website/shared/libraries/jquery.extra.fbf31263f39294c52d3a5cc6a2f6b309.gz.js'},{'src': 'http://static.politico.com/resource/js/website/shared/libraries/popup.26b0ff7e738340d74b9af4387fb60a39.gz.js'},{'src': 'http://static.politico.com/resource/js/website/shared/libraries/jquery-frame.50efb8f6cd88400053a419dfaa93e089.gz.js'},{'src': 'http://static.politico.com/resource/assets/js.min/main.4b4816da022fdc40bf99c496c150e4e1.gz.js'},{'src': 'http://static.politico.com/resource/assets/js.min/bsp.2de22c254625fff619553fa79c05348f.gz.js'},{'src': 'http://static.politico.com/resource/assets/js.min/election/2016/main.min.4e8424a226e711250160908e590373ac.gz.js'},{'src': 'http://static.politico.com/resource/assets/js.min/election/2016/election.min.a0d672489787d7d63eec76fecfd76f9a.gz.js'},{'src': '//s7.addthis.com/js/300/addthis_widget.js#pubid=politico.com'},{'inline': function() { buildSocial(); } },];POLITICO_Script_Loader.loadScriptsSync(scripts);
#    </script>
#   </div>
#  </body>
# </html>

# %% [markdown]
# ### parse beautiful soup object for presidential caucus results

# %%
df_results_cauc = pd.DataFrame()
for i in range(51):
    qs = soup.find_all('article', "timeline-group")[i]
    state = qs.a.text.strip("\n").strip(" ")
    electiontype = qs.find_all("a")[1].text.strip("\n").strip(" ")
    #print (state, electiontype)
    
    if electiontype == "Presidential Caucus":
        
        tables = qs.find_all('table')
        [x.get_text() for x in tables]
        out = []
        for table in tables:
            tout = []
            for row in table.find_all('tr'):
                rout = []
                rout.append(row.find('span').get_text())
                for column in row.find_all('td'):
                    rout.append(column.get_text())
                tout.append(rout)
            out.append(tout)
        
        details = qs.find_all('div', "title")
        for i in np.arange(len(details)):
            if details[i].find_all(text='Democratic') == ['Democratic']:
                party = 'DEM'
                electiontype = details[i-1].find("a").text.strip("\n").strip(" ")
                date = details[i-1].time['datetime']
                demresults = pd.DataFrame(out[(int((i-1)/2))])
                demresults['party'] = 'DEM'
                demresults['electiontype'] = electiontype
                demresults['state'] = state
                demresults['date'] = date
                df_results_cauc = df_results_cauc.append(demresults, ignore_index=True)
            if details[i].find_all(text='Republican') == ['Republican']:
                party = 'GOP'
                electiontype = details[i-1].find("a").text.strip("\n").strip(" ")
                date = details[i-1].time['datetime']
                gopresults = pd.DataFrame(out[(int((i-1)/2))])
                gopresults['party'] = 'GOP'
                gopresults['electiontype'] = electiontype
                gopresults['state'] = state
                gopresults['date'] = date
                df_results_cauc = df_results_cauc.append(gopresults, ignore_index=True)

# %%
df_results_cauc
# Out:
#                       0      1        2   3 party          electiontype  \
# 0        Winner T. Cruz  36.4%    7,973  12   GOP   Presidential Caucus
# 1              D. Trump  33.5%    7,346  11   GOP   Presidential Caucus
# 2              M. Rubio  15.1%    3,318   5   GOP   Presidential Caucus
# 3             B. Carson  10.9%    2,401       GOP   Presidential Caucus
# 4             J. Kasich   4.1%      892       GOP   Presidential Caucus
# 5           Uncommitted   0.0%        0       GOP   Presidential Caucus
# 6     Winner B. Sanders  81.6%      440  14   DEM   Presidential Caucus
# 7            H. Clinton  18.4%       99   4   DEM   Presidential Caucus
# 8       R. De La Fuente   0.0%        0       DEM   Presidential Caucus
# 9           Uncommitted   0.0%        0   2   DEM   Presidential Caucus
# 10    Winner B. Sanders  58.9%   71,928  38   DEM   Presidential Caucus
# 11           H. Clinton  40.4%   49,256  40   DEM   Presidential Caucus
# 12          Uncommitted   0.7%      819       DEM   Presidential Caucus
# 13                Other   0.0%       48       DEM   Presidential Caucus
# 14      Winner M. Rubio  37.3%    1,059  10   GOP   Presidential Caucus
# 15            J. Kasich  35.5%    1,009   9   GOP   Presidential Caucus
# 16             D. Trump  13.8%      391       GOP   Presidential Caucus
# 17              T. Cruz  12.4%      351       GOP   Presidential Caucus
# 18              J. Bush   0.5%       14       GOP   Presidential Caucus
# 19              R. Paul   0.4%       12       GOP   Presidential Caucus
# 20            B. Carson   0.1%        3       GOP   Presidential Caucus
# 21           C. Fiorina   0.0%        0       GOP   Presidential Caucus
# 22    Winner H. Clinton  78.7%   75,223  37   DEM  Presidential Primary
# 23           B. Sanders  21.1%   20,137   6   DEM  Presidential Primary
# 24      R. De La Fuente   0.2%      205       DEM  Presidential Primary
# 25      Winner D. Trump  42.4%    5,677  10   GOP   Presidential Caucus
# 26              T. Cruz  32.7%    4,379   6   GOP   Presidential Caucus
# 27             M. Rubio  13.1%    1,759       GOP   Presidential Caucus
# 28            J. Kasich  10.6%    1,413       GOP   Presidential Caucus
# 29            B. Carson   0.9%      127       GOP   Presidential Caucus
# ..                  ...    ...      ...  ..   ...                   ...
# 104         M. Huckabee   0.0%       21       GOP   Presidential Caucus
# 105         R. Santorum   0.0%       11       GOP   Presidential Caucus
# 106   Winner B. Sanders  64.2%      253  14   DEM   Presidential Caucus
# 107          H. Clinton  25.6%      101   6   DEM   Presidential Caucus
# 108         Uncommitted  10.2%       40   3   DEM   Presidential Caucus
# 109     R. De La Fuente   0.0%        0       DEM   Presidential Caucus
# 110             K. Judd   0.0%        0       DEM   Presidential Caucus
# 111               Other   0.0%        0       DEM   Presidential Caucus
# 112           W. Wilson   0.0%        0       DEM   Presidential Caucus
# 113   Winner B. Sanders  72.7%   19,159  23   DEM   Presidential Caucus
# 114          H. Clinton  27.1%    7,140  21   DEM   Presidential Caucus
# 115         Uncommitted   0.2%       46   4   DEM   Presidential Caucus
# 116               Other   0.0%        0       DEM   Presidential Caucus
# 117     Winner D. Trump  75.8%  403,003  40   GOP  Presidential Primary
# 118             T. Cruz  10.5%   55,719       GOP  Presidential Primary
# 119           J. Kasich   9.8%   52,129       GOP  Presidential Primary
# 120           B. Carson   3.9%   20,646       GOP  Presidential Primary
# 121             T. Cruz  66.3%      644   9   GOP   Presidential Caucus
# 122            M. Rubio  19.5%      189   1   GOP   Presidential Caucus
# 123            D. Trump   7.2%       70   1   GOP   Presidential Caucus
# 124         Uncommitted   7.0%       68   4   GOP   Presidential Caucus
# 125           B. Carson   0.0%        0       GOP   Presidential Caucus
# 126           J. Kasich   0.0%        0       GOP   Presidential Caucus
# 127               Other   0.0%        0       GOP   Presidential Caucus
# 128             R. Paul   0.0%        0       GOP   Presidential Caucus
# 129   Winner B. Sanders  55.7%      156   7   DEM   Presidential Caucus
# 130          H. Clinton  44.3%      124  11   DEM   Presidential Caucus
# 131     R. De La Fuente   0.0%        0       DEM   Presidential Caucus
# 132               Other   0.0%        0       DEM   Presidential Caucus
# 133         Uncommitted   0.0%        0       DEM   Presidential Caucus
#
#                     state        date
# 0                  Alaska  2016-03-01
# 1                  Alaska  2016-03-01
# 2                  Alaska  2016-03-01
# 3                  Alaska  2016-03-01
# 4                  Alaska  2016-03-01
# 5                  Alaska  2016-03-01
# 6                  Alaska  2016-03-26
# 7                  Alaska  2016-03-26
# 8                  Alaska  2016-03-26
# 9                  Alaska  2016-03-26
# 10               Colorado  2016-03-01
# 11               Colorado  2016-03-01
# 12               Colorado  2016-03-01
# 13               Colorado  2016-03-01
# 14   District of Columbia  2016-03-12
# 15   District of Columbia  2016-03-12
# 16   District of Columbia  2016-03-12
# 17   District of Columbia  2016-03-12
# 18   District of Columbia  2016-03-12
# 19   District of Columbia  2016-03-12
# 20   District of Columbia  2016-03-12
# 21   District of Columbia  2016-03-12
# 22   District of Columbia  2016-06-14
# 23   District of Columbia  2016-06-14
# 24   District of Columbia  2016-06-14
# 25                 Hawaii  2016-03-08
# 26                 Hawaii  2016-03-08
# 27                 Hawaii  2016-03-08
# 28                 Hawaii  2016-03-08
# 29                 Hawaii  2016-03-08
# ..                    ...         ...
# 104                Nevada  2016-02-23
# 105                Nevada  2016-02-23
# 106          North Dakota  2016-06-07
# 107          North Dakota  2016-06-07
# 108          North Dakota  2016-06-07
# 109          North Dakota  2016-06-07
# 110          North Dakota  2016-06-07
# 111          North Dakota  2016-06-07
# 112          North Dakota  2016-06-07
# 113            Washington  2016-03-26
# 114            Washington  2016-03-26
# 115            Washington  2016-03-26
# 116            Washington  2016-03-26
# 117            Washington  2016-05-24
# 118            Washington  2016-05-24
# 119            Washington  2016-05-24
# 120            Washington  2016-05-24
# 121               Wyoming  2016-03-12
# 122               Wyoming  2016-03-12
# 123               Wyoming  2016-03-12
# 124               Wyoming  2016-03-12
# 125               Wyoming  2016-03-12
# 126               Wyoming  2016-03-12
# 127               Wyoming  2016-03-12
# 128               Wyoming  2016-03-12
# 129               Wyoming  2016-04-09
# 130               Wyoming  2016-04-09
# 131               Wyoming  2016-04-09
# 132               Wyoming  2016-04-09
# 133               Wyoming  2016-04-09
#
# [134 rows x 8 columns]

# %% [markdown]
# ### parse election results labeled "presidential primaries" and "presidential caucuses"
# Doing this because the results are arranged differently for presidential primaries and democratic and republican caucuses that happened together.

# %%
df_results_prim = pd.DataFrame()
for i in range(51):
    qs = soup.find_all('article', "timeline-group")[i]
    state = qs.a.text.strip("\n").strip(" ")
    electiontype = qs.find_all("a")[1].text.strip("\n").strip(" ")
    date = qs.time['datetime']
    
    if electiontype == "Presidential Primaries" or  electiontype == "Presidential Caucuses":
        tables = qs.find_all('table')
        [x.get_text() for x in tables]
        out = []
        for table in tables:
            tout = []
            for row in table.find_all('tr'):
                rout = []
                rout.append(row.find('span').get_text())
                for column in row.find_all('td'):
                    rout.append(column.get_text())
                tout.append(rout)
            out.append(tout)
            
        demresults = pd.DataFrame(out[0])
        demresults['party'] = 'DEM'
        demresults['electiontype'] = electiontype
        demresults['state'] = state
        demresults['date'] = date
        df_results_prim = df_results_prim.append(demresults, ignore_index=True)
        gopresults = pd.DataFrame(out[1])
        gopresults['party'] = 'GOP'
        gopresults['electiontype'] = electiontype
        gopresults['state'] = state
        gopresults['date'] = date
        df_results_prim = df_results_prim.append(gopresults, ignore_index=True)

# %%
df_results_prim
# Out:
#                       0      1        2    3 party            electiontype  \
# 0     Winner H. Clinton  77.8%  309,928   51   DEM  Presidential Primaries
# 1            B. Sanders  19.2%   76,399    9   DEM  Presidential Primaries
# 2           Uncommitted   2.4%    9,534        DEM  Presidential Primaries
# 3           M. O'Malley   0.4%    1,489        DEM  Presidential Primaries
# 4       R. De La Fuente   0.2%      814        DEM  Presidential Primaries
# 5       Winner D. Trump  43.4%  371,735   36   GOP  Presidential Primaries
# 6               T. Cruz  21.1%  180,608   13   GOP  Presidential Primaries
# 7              M. Rubio  18.7%  159,802    1   GOP  Presidential Primaries
# 8             B. Carson  10.2%   87,517        GOP  Presidential Primaries
# 9             J. Kasich   4.4%   37,970        GOP  Presidential Primaries
# 10          Uncommitted   0.9%    7,911        GOP  Presidential Primaries
# 11              J. Bush   0.5%    3,946        GOP  Presidential Primaries
# 12          M. Huckabee   0.3%    2,535        GOP  Presidential Primaries
# 13              R. Paul   0.2%    1,879        GOP  Presidential Primaries
# 14          C. Christie   0.1%      850        GOP  Presidential Primaries
# 15          R. Santorum   0.1%      616        GOP  Presidential Primaries
# 16           C. Fiorina   0.1%      543        GOP  Presidential Primaries
# 17            L. Graham   0.0%      254        GOP  Presidential Primaries
# 18    Winner H. Clinton  57.6%  235,697  NaN   DEM  Presidential Primaries
# 19           B. Sanders  39.9%  163,400  NaN   DEM  Presidential Primaries
# 20          M. O'Malley   0.9%    3,599  NaN   DEM  Presidential Primaries
# 21      R. De La Fuente   0.6%    2,540  NaN   DEM  Presidential Primaries
# 22         M. Steinberg   0.5%    2,118  NaN   DEM  Presidential Primaries
# 23             H. Hewes   0.4%    1,659  NaN   DEM  Presidential Primaries
# 24      Winner D. Trump  47.1%  249,916  NaN   GOP  Presidential Primaries
# 25              T. Cruz  24.9%  132,147  NaN   GOP  Presidential Primaries
# 26             M. Rubio  13.3%   70,556  NaN   GOP  Presidential Primaries
# 27            J. Kasich  10.0%   53,040  NaN   GOP  Presidential Primaries
# 28            B. Carson   2.7%   14,321  NaN   GOP  Presidential Primaries
# 29              J. Bush   0.8%    4,076  NaN   GOP  Presidential Primaries
# ..                  ...    ...      ...  ...   ...                     ...
# 560         M. O'Malley   1.6%    3,781        DEM  Presidential Primaries
# 561     R. De La Fuente   0.4%    1,010        DEM  Presidential Primaries
# 562     Winner D. Trump  77.0%  156,245   32   GOP  Presidential Primaries
# 563             T. Cruz   9.0%   18,208        GOP  Presidential Primaries
# 564           J. Kasich   6.7%   13,685    1   GOP  Presidential Primaries
# 565           B. Carson   2.2%    4,397        GOP  Presidential Primaries
# 566            M. Rubio   1.4%    2,895        GOP  Presidential Primaries
# 567             J. Bush   1.1%    2,298        GOP  Presidential Primaries
# 568             R. Paul   0.9%    1,789        GOP  Presidential Primaries
# 569         M. Huckabee   0.9%    1,770        GOP  Presidential Primaries
# 570         C. Christie   0.4%      723        GOP  Presidential Primaries
# 571          C. Fiorina   0.3%      658        GOP  Presidential Primaries
# 572             D. Hall   0.1%      212        GOP  Presidential Primaries
# 573   Winner B. Sanders  56.6%  567,936   49   DEM  Presidential Primaries
# 574          H. Clinton  43.1%  432,767   47   DEM  Presidential Primaries
# 575         M. O'Malley   0.2%    1,765        DEM  Presidential Primaries
# 576        Uninstructed   0.1%    1,436        DEM  Presidential Primaries
# 577      Winner T. Cruz  48.2%  531,129   36   GOP  Presidential Primaries
# 578            D. Trump  35.1%  386,370    6   GOP  Presidential Primaries
# 579           J. Kasich  14.1%  155,200        GOP  Presidential Primaries
# 580            M. Rubio   1.0%   10,569        GOP  Presidential Primaries
# 581           B. Carson   0.5%    5,608        GOP  Presidential Primaries
# 582             J. Bush   0.3%    3,153        GOP  Presidential Primaries
# 583             R. Paul   0.2%    2,491        GOP  Presidential Primaries
# 584        Uninstructed   0.2%    2,288        GOP  Presidential Primaries
# 585         M. Huckabee   0.1%    1,428        GOP  Presidential Primaries
# 586         C. Christie   0.1%    1,310        GOP  Presidential Primaries
# 587          C. Fiorina   0.1%      825        GOP  Presidential Primaries
# 588         R. Santorum   0.0%      510        GOP  Presidential Primaries
# 589          J. Gilmore   0.0%      242        GOP  Presidential Primaries
#
#              state        date
# 0          Alabama  2016-03-01
# 1          Alabama  2016-03-01
# 2          Alabama  2016-03-01
# 3          Alabama  2016-03-01
# 4          Alabama  2016-03-01
# 5          Alabama  2016-03-01
# 6          Alabama  2016-03-01
# 7          Alabama  2016-03-01
# 8          Alabama  2016-03-01
# 9          Alabama  2016-03-01
# 10         Alabama  2016-03-01
# 11         Alabama  2016-03-01
# 12         Alabama  2016-03-01
# 13         Alabama  2016-03-01
# 14         Alabama  2016-03-01
# 15         Alabama  2016-03-01
# 16         Alabama  2016-03-01
# 17         Alabama  2016-03-01
# 18         Arizona  2016-03-22
# 19         Arizona  2016-03-22
# 20         Arizona  2016-03-22
# 21         Arizona  2016-03-22
# 22         Arizona  2016-03-22
# 23         Arizona  2016-03-22
# 24         Arizona  2016-03-22
# 25         Arizona  2016-03-22
# 26         Arizona  2016-03-22
# 27         Arizona  2016-03-22
# 28         Arizona  2016-03-22
# 29         Arizona  2016-03-22
# ..             ...         ...
# 560  West Virginia  2016-05-10
# 561  West Virginia  2016-05-10
# 562  West Virginia  2016-05-10
# 563  West Virginia  2016-05-10
# 564  West Virginia  2016-05-10
# 565  West Virginia  2016-05-10
# 566  West Virginia  2016-05-10
# 567  West Virginia  2016-05-10
# 568  West Virginia  2016-05-10
# 569  West Virginia  2016-05-10
# 570  West Virginia  2016-05-10
# 571  West Virginia  2016-05-10
# 572  West Virginia  2016-05-10
# 573      Wisconsin  2016-04-05
# 574      Wisconsin  2016-04-05
# 575      Wisconsin  2016-04-05
# 576      Wisconsin  2016-04-05
# 577      Wisconsin  2016-04-05
# 578      Wisconsin  2016-04-05
# 579      Wisconsin  2016-04-05
# 580      Wisconsin  2016-04-05
# 581      Wisconsin  2016-04-05
# 582      Wisconsin  2016-04-05
# 583      Wisconsin  2016-04-05
# 584      Wisconsin  2016-04-05
# 585      Wisconsin  2016-04-05
# 586      Wisconsin  2016-04-05
# 587      Wisconsin  2016-04-05
# 588      Wisconsin  2016-04-05
# 589      Wisconsin  2016-04-05
#
# [590 rows x 8 columns]

# %% [markdown]
# # Append dateframe of presidential primaries to dataframe of presidential caucuses

# %%
print ("length of primaries dataframe: {}".format(len(df_results_prim)))
print ("length of caucus dataframe: {}".format(len(df_results_cauc)))
df_results = df_results_prim.append(df_results_cauc, ignore_index=True)
print ("length of results dataframe: {}".format(len(df_results)))
# Out:
# length of primaries dataframe: 590
# length of caucus dataframe: 134
# length of results dataframe: 724

# %%
df_results.rename(columns={0: 'candidate', 1: '%votes', 2: 'votes', 3:'delegates'}, inplace=True)

# %%
df_results.sort(['electiontype', 'state', 'date','party'], inplace=True)
# Out:
# /Users/baileygriswold/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
df_results.set_index(['electiontype', 'state', 'date', 'party'], inplace=True)

# %%
df_results
# Out:
#                                                                      candidate  \
# electiontype         state                date       party
# Presidential Caucus  Alaska               2016-03-01 GOP        Winner T. Cruz
#                                                      GOP              D. Trump
#                                                      GOP              M. Rubio
#                                                      GOP             B. Carson
#                                                      GOP             J. Kasich
#                                                      GOP           Uncommitted
#                                           2016-03-26 DEM     Winner B. Sanders
#                                                      DEM            H. Clinton
#                                                      DEM       R. De La Fuente
#                                                      DEM           Uncommitted
#                      Colorado             2016-03-01 DEM     Winner B. Sanders
#                                                      DEM            H. Clinton
#                                                      DEM           Uncommitted
#                                                      DEM                 Other
#                      District of Columbia 2016-03-12 GOP       Winner M. Rubio
#                                                      GOP             J. Kasich
#                                                      GOP              D. Trump
#                                                      GOP               T. Cruz
#                                                      GOP               J. Bush
#                                                      GOP               R. Paul
#                                                      GOP             B. Carson
#                                                      GOP            C. Fiorina
#                      Hawaii               2016-03-08 GOP       Winner D. Trump
#                                                      GOP               T. Cruz
#                                                      GOP              M. Rubio
#                                                      GOP             J. Kasich
#                                                      GOP             B. Carson
#                                                      GOP               J. Bush
#                                           2016-03-26 DEM     Winner B. Sanders
#                                                      DEM            H. Clinton
# ...                                                                        ...
# Presidential Primary District of Columbia 2016-06-14 DEM     Winner H. Clinton
#                                                      DEM            B. Sanders
#                                                      DEM       R. De La Fuente
#                      Idaho                2016-03-08 GOP        Winner T. Cruz
#                                                      GOP              D. Trump
#                                                      GOP              M. Rubio
#                                                      GOP             J. Kasich
#                                                      GOP             B. Carson
#                                                      GOP               J. Bush
#                                                      GOP               R. Paul
#                                                      GOP           M. Huckabee
#                                                      GOP           C. Christie
#                                                      GOP            C. Fiorina
#                                                      GOP           R. Santorum
#                                                      GOP             L. Graham
#                                                      GOP            P. Messina
#                      Kentucky             2016-05-17 DEM            H. Clinton
#                                                      DEM            B. Sanders
#                                                      DEM           Uncommitted
#                                                      DEM           M. O'Malley
#                                                      DEM       R. De La Fuente
#                      Nebraska             2016-05-10 GOP       Winner D. Trump
#                                                      GOP               T. Cruz
#                                                      GOP             J. Kasich
#                                                      GOP             B. Carson
#                                                      GOP              M. Rubio
#                      Washington           2016-05-24 GOP       Winner D. Trump
#                                                      GOP               T. Cruz
#                                                      GOP             J. Kasich
#                                                      GOP             B. Carson
#
#                                                            %votes    votes  \
# electiontype         state                date       party
# Presidential Caucus  Alaska               2016-03-01 GOP    36.4%    7,973
#                                                      GOP    33.5%    7,346
#                                                      GOP    15.1%    3,318
#                                                      GOP    10.9%    2,401
#                                                      GOP     4.1%      892
#                                                      GOP     0.0%        0
#                                           2016-03-26 DEM    81.6%      440
#                                                      DEM    18.4%       99
#                                                      DEM     0.0%        0
#                                                      DEM     0.0%        0
#                      Colorado             2016-03-01 DEM    58.9%   71,928
#                                                      DEM    40.4%   49,256
#                                                      DEM     0.7%      819
#                                                      DEM     0.0%       48
#                      District of Columbia 2016-03-12 GOP    37.3%    1,059
#                                                      GOP    35.5%    1,009
#                                                      GOP    13.8%      391
#                                                      GOP    12.4%      351
#                                                      GOP     0.5%       14
#                                                      GOP     0.4%       12
#                                                      GOP     0.1%        3
#                                                      GOP     0.0%        0
#                      Hawaii               2016-03-08 GOP    42.4%    5,677
#                                                      GOP    32.7%    4,379
#                                                      GOP    13.1%    1,759
#                                                      GOP    10.6%    1,413
#                                                      GOP     0.9%      127
#                                                      GOP     0.2%       22
#                                           2016-03-26 DEM    69.8%   23,530
#                                                      DEM    30.0%   10,125
# ...                                                           ...      ...
# Presidential Primary District of Columbia 2016-06-14 DEM    78.7%   75,223
#                                                      DEM    21.1%   20,137
#                                                      DEM     0.2%      205
#                      Idaho                2016-03-08 GOP    45.4%  100,942
#                                                      GOP    28.1%   62,478
#                                                      GOP    15.9%   35,347
#                                                      GOP     7.4%   16,517
#                                                      GOP     1.7%    3,887
#                                                      GOP     0.4%      938
#                                                      GOP     0.4%      834
#                                                      GOP     0.2%      356
#                                                      GOP     0.2%      355
#                                                      GOP     0.1%      241
#                                                      GOP     0.1%      211
#                                                      GOP     0.0%       80
#                                                      GOP     0.0%       27
#                      Kentucky             2016-05-17 DEM    46.8%  212,550
#                                                      DEM    46.3%  210,626
#                                                      DEM     5.3%   24,101
#                                                      DEM     1.3%    5,703
#                                                      DEM     0.4%    1,593
#                      Nebraska             2016-05-10 GOP    61.4%  121,287
#                                                      GOP    18.4%   36,418
#                                                      GOP    11.4%   22,526
#                                                      GOP     5.1%   10,029
#                                                      GOP     3.6%    7,170
#                      Washington           2016-05-24 GOP    75.8%  403,003
#                                                      GOP    10.5%   55,719
#                                                      GOP     9.8%   52,129
#                                                      GOP     3.9%   20,646
#
#                                                            delegates
# electiontype         state                date       party
# Presidential Caucus  Alaska               2016-03-01 GOP          12
#                                                      GOP          11
#                                                      GOP           5
#                                                      GOP
#                                                      GOP
#                                                      GOP
#                                           2016-03-26 DEM          14
#                                                      DEM           4
#                                                      DEM
#                                                      DEM           2
#                      Colorado             2016-03-01 DEM          38
#                                                      DEM          40
#                                                      DEM
#                                                      DEM
#                      District of Columbia 2016-03-12 GOP          10
#                                                      GOP           9
#                                                      GOP
#                                                      GOP
#                                                      GOP
#                                                      GOP
#                                                      GOP
#                                                      GOP
#                      Hawaii               2016-03-08 GOP          10
#                                                      GOP           6
#                                                      GOP
#                                                      GOP
#                                                      GOP
#                                                      GOP
#                                           2016-03-26 DEM          20
#                                                      DEM          12
# ...                                                              ...
# Presidential Primary District of Columbia 2016-06-14 DEM          37
#                                                      DEM           6
#                                                      DEM
#                      Idaho                2016-03-08 GOP          20
#                                                      GOP          12
#                                                      GOP
#                                                      GOP
#                                                      GOP
#                                                      GOP
#                                                      GOP
#                                                      GOP
#                                                      GOP
#                                                      GOP
#                                                      GOP
#                                                      GOP
#                                                      GOP
#                      Kentucky             2016-05-17 DEM          30
#                                                      DEM          27
#                                                      DEM           1
#                                                      DEM
#                                                      DEM
#                      Nebraska             2016-05-10 GOP          36
#                                                      GOP
#                                                      GOP
#                                                      GOP
#                                                      GOP
#                      Washington           2016-05-24 GOP          40
#                                                      GOP
#                                                      GOP
#                                                      GOP
#
# [724 rows x 4 columns]

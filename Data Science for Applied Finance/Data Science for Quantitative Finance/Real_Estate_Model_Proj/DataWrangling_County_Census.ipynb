# %% [markdown]
# Download all census datasets (5 year estimates from every year from 2010-2016). Format dataframes, drop columns with >40% NaN, and impute NaNs in the rest of the dataframe. Final output is a pkl of the dictionary where each enry is a dictionary for each of the datasets (economic, social, demographics, housing, and migration). Each dataset dictionary has an entry for each year.
#
# Data source: downloaded on county level from the American Factfinder website.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as pl
import datetime
import pickle

from fancyimpute import KNN

# %%
def column_filter(df,phrase):
    '''produces a list of columns that contain the phrase'''
    start_len = len(df.columns)
    keep_cols = []
    for i in df.columns:
        if phrase in i:
            keep_cols.append(i)
    #print ('Columns matching filter: {}'.format(len(keep_cols)))
    return (keep_cols)

# %%
def drop_columns(df,phrase,dropped_cols=False):
    '''Drop all columns in dataframe df that contain substring phrase'''
    start_len = len(df.columns)
    drop_cols = []
    for i in df.columns:
        if phrase in i:
            drop_cols.append(i)
            df.drop([i], axis=1, inplace=True)
    #print ('Total Columns Dropped: {}'.format(len(drop_cols)))
    if dropped_cols == True:
        print ('Dropped Columns: {}'.format(drop_cols))

# %%
def process_acs_data(census_dict):
    '''Format census data and drop irrelevant columns'''
    for yr in census_dict.keys():
        census_dict[yr].columns = census_dict[yr].iloc[0]
        census_dict[yr] = census_dict[yr].reindex(census_dict[yr].index.drop(0))
        
        try:
            census_dict[yr].rename(columns={'Id2': 'FIPS'}, inplace=True) 
                                                  #if keeping descriptive features
            census_dict[yr].drop(['Id', 'Geography'], axis=1, inplace=True) 
                                                  #if keeping descriptive features
        except ValueError:
            pass

        #census_dict[yr].rename(columns={'GEO.id2': 'FIPS'}, inplace=True) 
                                                  #if keeping feature codes
        #census_dict[yr].drop(['index', 'GEO.id', 'GEO.display-label'], axis=1, inplace=True) 
                                                  #if keeping feature codes


        #dropping irrelevant features
        drop_columns(census_dict[yr], 'Margin of Error')
        perc = column_filter(census_dict[yr], 'Percent')
        mean = column_filter(census_dict[yr], 'Mean')
        median = column_filter(census_dict[yr], 'Median')
        a = (perc + mean  + median)
        a.append('FIPS')
        census_dict[yr] = census_dict[yr][a]


        #dropping values that are totals and not normalized
                        #-- assuming percents are there already
        try: 
            census_dict[yr].drop(['Percent; EMPLOYMENT STATUS - Civilian labor force',
             'Percent; EMPLOYMENT STATUS - Females 16 years and over',
             'Percent; EMPLOYMENT STATUS - Own children under 6 years',
             'Percent; EMPLOYMENT STATUS - Own children 6 to 17 years',
             'Percent; COMMUTING TO WORK - Workers 16 years and over',
             'Percent; OCCUPATION - Civilian employed population 16 years and over',
             'Percent; INDUSTRY - Civilian employed population 16 years and over',
             'Percent; CLASS OF WORKER - Civilian employed population 16 years and over',
             'Percent; INCOME AND BENEFITS (IN 2010 INFLATION-ADJUSTED DOLLARS) - Total census_dicteholds',
             'Percent; INCOME AND BENEFITS (IN 2010 INFLATION-ADJUSTED DOLLARS) - Families',
             'Percent; INCOME AND BENEFITS (IN 2010 INFLATION-ADJUSTED DOLLARS) - Nonfamily census_dicteholds',
             'Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population',
             'Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population under 18 years',
             'Percent; HEALTH INSURANCE COVERAGE - Civilian noninstitutionalized population 18 to 64 years',
             'Percent; HEALTH INSURANCE COVERAGE - In labor force:',
             'Percent; HEALTH INSURANCE COVERAGE - In labor force: - Employed:',
             'Percent; HEALTH INSURANCE COVERAGE - In labor force: - Unemployed:',
             'Percent; HEALTH INSURANCE COVERAGE - Not in labor force:'], axis=1, inplace=True)
        except ValueError:
            pass

        #formatting FIPS and numeric
        census_dict[yr] = census_dict[yr].apply(pd.to_numeric, errors='coerce')
        census_dict[yr]['FIPS'] = census_dict[yr]['FIPS'].apply(str)
        census_dict[yr]['FIPS'] = census_dict[yr]['FIPS'].str.zfill(5)

        #dropping NaN columns
        census_dict[yr].dropna(axis=1, how='all', inplace=True)

        census_dict[yr].columns = census_dict[yr].columns.str.replace(' ', '_')
        census_dict[yr].columns = census_dict[yr].columns.str.replace(';', '_')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('.', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace(',', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('(', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace(')', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('"', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace("'", '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('-', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace(':', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('$', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('2010', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('2011', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('2012', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('2013', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('2014', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('2015', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('2016', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('__Civilian_employed_population_16_years_and_over', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('__Workers_16_years_and_over', '')
        
        try: 
            census_dict[yr].drop(['Percent__INCOME_AND_BENEFITS_IN__INFLATIONADJUSTED_DOLLARS__Families__150000_to_199999',
             'Percent__INCOME_AND_BENEFITS_IN__INFLATIONADJUSTED_DOLLARS__Families__150000_to_199999_log',
             'Percent__INCOME_AND_BENEFITS_IN__INFLATIONADJUSTED_DOLLARS__Families__200000_or_more',
             'Percent__INCOME_AND_BENEFITS_IN__INFLATIONADJUSTED_DOLLARS__Families__200000_or_more_log', 
             'Estimate__SELECTED_MONTHLY_OWNER_COSTS_SMOC__Housing_units_without_a_mortgage__Median_dollars',
             'Estimate__SELECTED_MONTHLY_OWNER_COSTS_SMOC__Housing_units_without_a_mortgage__Median_dollars_log'], axis=1, inplace=True)
        except ValueError:
            pass
        
        #census_dict[yr].columns = census_dict[yr].columns.str.replace('Families__', '')
        #census_dict[yr].columns = census_dict[yr].columns.str.replace('Nonfamily_households__', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('Total_households__', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('Occupied_units_paying_rent__', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('Total_population__', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('Housing_units_with_a_mortgage__', '') 
        census_dict[yr].columns = census_dict[yr].columns.str.replace('Population_25_years_and_over__', '')

        census_dict[yr].columns = census_dict[yr].columns.str.replace('Owneroccupied_units__', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('Total_housing_units__', '')
        #census_dict[yr].columns = census_dict[yr].columns.str.replace('Population_5_years_and_over__', '')
        census_dict[yr].columns = census_dict[yr].columns.str.replace('Race_alone_or_in_combination_with_one_or_more_other_races__', '')

        #dropping dup columns

        census_dict[yr] = census_dict[yr].loc[:,~census_dict[yr].columns.duplicated()]       
        print ('Columns after processing:{} \n'.format(len(census_dict[yr].columns)))                                         

    return census_dict

# %% [markdown]
# Load all dataframe dictionaries with county data, and combine multi years into single dataframes, indexed on FIPS
# - economic data --> ** econ_df **
#     - FIPS, feature, time series by year (2010-2016)
#     - FIPS is in str form with padded 0
#     - feature codes are listed in this doc: ACS_14_1YR_DP03_metadata.csv
#     - be careful when merging later: demographic data (housing, econ, social, acs) all have the same codes that refer to different things. Add a prefix or suffix to denote which category the code refers to
# - housing data --> ** hous_df  **
#     - FIPS, feature, time series by year (2010-2016)
#     - FIPS is str, padded 0
#     - feature codes are listed in this doc: ACS_14_1YR_DP04_metadata.csv
# - Social demographics --> ** soc_df **
#     - FIPS, feature, time series by year (2010-2016)
#     - FIPS is str, padded 0
#     - feature codes are listed in this doc: ACS_14_1YR_DP02_metadata.csv
# - Race, Age, gender--> ** dem_df **
#     - FIPS, feature, time series by year (2010-2016)
#     - FIPS is str, padded 0
#     - feature codes are listed in this doc: ACS_14_1YR_DP05_metadata.csv
# - population profile --> ** pop_df **
#     - FIPS, feature, time series by year (2005-2016)
#     - FIPS is str, padded 0
#     - feature codes are listed in this doc: ACS_05_EST_S0201_metadata.csv
#     - race codes are attached at the end of each feature code
#         - for example: feature code EST_VC01 refers to the Estimate; Total population
#         - the race code '001' refers to the total population
#         - the race code '002' refers to whites
#         - therefore, a feature with the code 'EST_VC01_001' would refer to the total population size in a particular county. A feature with the code 'EST_VC01-002' would refer to the total population size of only white constituents of that particular county.
#     - Race code references are stores in the dictionary: id_groups
# - migration stats --> ** migr_df **
#     - FIPS, feature, time series by year (2011-2016)
#     - FIPS is str, padded 0
#     - feature codes are listed in this doc: PEP_2011_PEPTCOMP_metadata.csv

# %% [markdown]
# #### DEMOGRAPHIC DATA

# %% [markdown]
# ## Loading Census DataFrames

# %% [markdown]
# ** * Economic Data from ACS * **

# %%
year = np.arange(10,17)

# %%
econ = {}
for yr in year:
    path = './data/Demographic_Data/ACS_{}_1YR_DP03/ACS_{}_1YR_DP03_with_ann.csv'.format(yr, yr)
    econ[yr] =  pd.read_csv(path, encoding = "ISO-8859-1")
    print (yr, 'Columns: ', len(econ[yr].columns), 'Counties: ', len(econ[yr]))
# Out:
# 10 Columns:  551 Counties:  808
# 11 Columns:  551 Counties:  812
# 12 Columns:  551 Counties:  815
# 13 Columns:  551 Counties:  818
# 14 Columns:  551 Counties:  818
# 15 Columns:  551 Counties:  820
# 16 Columns:  551 Counties:  821

# %%
econ = process_acs_data(econ)
# Out:
# Columns after processing:106
#
# Columns after processing:107
#
# Columns after processing:107
#
# Columns after processing:126
#
# Columns after processing:126
#
# Columns after processing:128
#
# Columns after processing:128

# %% [markdown]
# ** * Housing Data * **

# %%
hous = {}
for yr in year:
    path = './data/Demographic_Data/ACS_{}_1YR_DP04/ACS_{}_1YR_DP04_with_ann.csv'.format(yr, yr)
    hous[yr] =  pd.read_csv(path, encoding = "ISO-8859-1")
    print (yr, 'Columns: ', len(hous[yr].columns), 'Counties: ', len(hous[yr]))
# Out:
# 10 Columns:  567 Counties:  808
# 11 Columns:  567 Counties:  812
# 12 Columns:  567 Counties:  815
# 13 Columns:  567 Counties:  818
# 14 Columns:  567 Counties:  818
# 15 Columns:  575 Counties:  820
# 16 Columns:  575 Counties:  821

# %%
hous = process_acs_data(hous)
# Out:
# Columns after processing:129
#
# Columns after processing:129
#
# Columns after processing:129
#
# Columns after processing:134
#
# Columns after processing:134
#
# Columns after processing:136
#
# Columns after processing:136

# %% [markdown]
# ** * Social Demographics Data * **

# %%
soc = {}
for yr in year:
    path = './data/Demographic_Data/ACS_{}_1YR_DP02/ACS_{}_1YR_DP02_with_ann.csv'.format(yr, yr)
    soc[yr] =  pd.read_csv(path, encoding = "ISO-8859-1")
    print (yr, 'Columns: ', len(soc[yr].columns), 'Counties: ', len(soc[yr]))
# Out:
# 10 Columns:  599 Counties:  808
# 11 Columns:  599 Counties:  812
# 12 Columns:  599 Counties:  815
# 13 Columns:  611 Counties:  818
# 14 Columns:  611 Counties:  818
# 15 Columns:  611 Counties:  820
# 16 Columns:  611 Counties:  821

# %%
soc = process_acs_data(soc)
# Out:
# Columns after processing:133
#
# Columns after processing:133
#
# Columns after processing:133
#
# Columns after processing:146
#
# Columns after processing:146
#
# Columns after processing:146
#
# Columns after processing:146

# %% [markdown]
# ** * Race, Age, Gender * **

# %%
dem = {}
for yr in year:
    path = './data/Demographic_Data/ACS_{}_1YR_DP05/ACS_{}_1YR_DP05_with_ann.csv'.format(yr, yr)
    dem[yr] =  pd.read_csv(path, encoding = "ISO-8859-1")
    print (yr, 'Columns: ', len(dem[yr].columns), 'Counties: ', len(dem[yr]))
# Out:
# 10 Columns:  327 Counties:  808
# 11 Columns:  327 Counties:  812
# 12 Columns:  327 Counties:  815
# 13 Columns:  327 Counties:  818
# 14 Columns:  327 Counties:  818
# 15 Columns:  339 Counties:  820
# 16 Columns:  339 Counties:  821

# %%
dem = process_acs_data(dem)
# Out:
# Columns after processing:72
#
# Columns after processing:72
#
# Columns after processing:72
#
# Columns after processing:76
#
# Columns after processing:76
#
# Columns after processing:79
#
# Columns after processing:79

# %% [markdown]
# ** * birth, death, migrations * **

# %%
years = np.arange(2011, 2017)

# %%
migr = {}
for yr in years:
    path = './data/County_Snapshots/Births_Death_Migration/PEP_{}_PEPTCOMP/PEP_{}_PEPTCOMP_with_ann.csv'.format(yr, yr)
    migr[yr] =  pd.read_csv(path, encoding = "ISO-8859-1")

    #replace the features codes with descriptive features
    migr[yr].columns = migr[yr].iloc[0]
    migr[yr] = migr[yr].reindex(migr[yr].index.drop(0))
    migr[yr]['Year'] = str(yr)
    
    try:
        migr[yr].rename(columns={'Id2': 'FIPS'}, inplace=True) #if keeping descriptive features
        migr[yr].drop(['Id', 'Geography'], axis=1, inplace=True) #if keeping descriptive features
    except ValueError:
        pass
    
    migr[yr].columns = migr[yr].columns.str.replace('2010', '')
    migr[yr].columns = migr[yr].columns.str.replace('2011', '')
    migr[yr].columns = migr[yr].columns.str.replace('2012', '')
    migr[yr].columns = migr[yr].columns.str.replace('2013', '')
    migr[yr].columns = migr[yr].columns.str.replace('2014', '')
    migr[yr].columns = migr[yr].columns.str.replace('2015', '')
    migr[yr].columns = migr[yr].columns.str.replace('2016', '')
    
    migr[yr].iloc[:, 1:] = migr[yr].iloc[:, 1:].apply(pd.to_numeric, errors='coerce')
    
    print (yr, 'Columns: ', len(migr[yr].columns), 'Counties: ', len(migr[yr]))
# Out:
# 2011 Columns:  16 Counties:  3143
# 2012 Columns:  16 Counties:  3143
# 2013 Columns:  16 Counties:  3143
# 2014 Columns:  16 Counties:  3142
# 2015 Columns:  16 Counties:  3142
# 2016 Columns:  16 Counties:  3142

# %% [markdown]
# There are way more counties in the migration dataset than in the other census datasets.

# %% [markdown]
# ## Handling NaNs

# %%
comm_dicts = [econ, soc, migr, dem, hous]

# %%
#setting dictionaries to have the same keys
for d in [econ, soc, dem, hous]:
    for yr in year:
        new_key = yr + 2000
        d[new_key] = d.pop(yr)

# %%
for d in comm_dicts:
    for yr in d.keys():
        print (yr, d[yr].isnull().sum().sort_values(ascending=False)[:10], '\n')
# Out:
# 2010 0
# Estimate__INCOME_AND_BENEFITS_IN__INFLATIONADJUSTED_DOLLARS__With_cash_public_assistance_income__Mean_cash_public_assistance_income_dollars    53
# Percent__OCCUPATION__Natural_resources_construction_and_maintenance_occupations                                                                 7
# Percent__OCCUPATION__Production_transportation_and_material_moving_occupations                                                                  7
# Percent__OCCUPATION__Sales_and_office_occupations                                                                                               7
# Percent__OCCUPATION__Service_occupations                                                                                                        7
# Percent__OCCUPATION__Management_business_science_and_arts_occupations                                                                           7
# Percent__COMMUTING_TO_WORK__Car_truck_or_van__drove_alone                                                                                       5
# Percent__COMMUTING_TO_WORK__Worked_at_home                                                                                                      5
# Percent__COMMUTING_TO_WORK__Other_means                                                                                                         5
# Percent__COMMUTING_TO_WORK__Walked                                                                                                              5
# dtype: int64
#
# 2011 0
# Estimate__INCOME_AND_BENEFITS_IN__INFLATIONADJUSTED_DOLLARS__With_cash_public_assistance_income__Mean_cash_public_assistance_income_dollars    86
# Percent__OCCUPATION__Production_transportation_and_material_moving_occupations                                                                 21
# Percent__OCCUPATION__Natural_resources_construction_and_maintenance_occupations                                                                21
# Percent__OCCUPATION__Sales_and_office_occupations                                                                                              21
# Percent__OCCUPATION__Service_occupations                                                                                                       21
# Percent__OCCUPATION__Management_business_science_and_arts_occupations                                                                          21
# Percent__COMMUTING_TO_WORK__Public_transportation_excluding_taxicab                                                                            10
# Percent__COMMUTING_TO_WORK__Other_means                                                                                                        10
# Percent__COMMUTING_TO_WORK__Car_truck_or_van__drove_alone                                                                                      10
# Percent__COMMUTING_TO_WORK__Car_truck_or_van__carpooled                                                                                        10
# dtype: int64
#
# 2012 0
# Estimate__INCOME_AND_BENEFITS_IN__INFLATIONADJUSTED_DOLLARS__With_cash_public_assistance_income__Mean_cash_public_assistance_income_dollars    41
# Percent__COMMUTING_TO_WORK__Public_transportation_excluding_taxicab                                                                             9
# Percent__COMMUTING_TO_WORK__Other_means                                                                                                         9
# Percent__COMMUTING_TO_WORK__Car_truck_or_van__drove_alone                                                                                       9
# Percent__COMMUTING_TO_WORK__Car_truck_or_van__carpooled                                                                                         9
# Percent__COMMUTING_TO_WORK__Worked_at_home                                                                                                      9
# Percent__COMMUTING_TO_WORK__Walked                                                                                                              9
# Percent__OCCUPATION__Production_transportation_and_material_moving_occupations                                                                  6
# Percent__OCCUPATION__Natural_resources_construction_and_maintenance_occupations                                                                 6
# Percent__OCCUPATION__Sales_and_office_occupations                                                                                               6
# dtype: int64
#
# 2013 0
# Estimate__INCOME_AND_BENEFITS_IN__INFLATIONADJUSTED_DOLLARS__With_cash_public_assistance_income__Mean_cash_public_assistance_income_dollars    51
# Percent__COMMUTING_TO_WORK__Worked_at_home                                                                                                     12
# Percent__COMMUTING_TO_WORK__Other_means                                                                                                        12
# Percent__COMMUTING_TO_WORK__Walked                                                                                                             12
# Percent__COMMUTING_TO_WORK__Public_transportation_excluding_taxicab                                                                            12
# Percent__COMMUTING_TO_WORK__Car_truck_or_van__carpooled                                                                                        12
# Percent__COMMUTING_TO_WORK__Car_truck_or_van__drove_alone                                                                                      12
# Percent__OCCUPATION__Natural_resources_construction_and_maintenance_occupations                                                                 8
# Percent__OCCUPATION__Sales_and_office_occupations                                                                                               8
# Percent__OCCUPATION__Service_occupations                                                                                                        8
# dtype: int64
#
# 2014 0
# Estimate__INCOME_AND_BENEFITS_IN__INFLATIONADJUSTED_DOLLARS__With_cash_public_assistance_income__Mean_cash_public_assistance_income_dollars                                                                                                      61
# Percent__COMMUTING_TO_WORK__Car_truck_or_van__drove_alone                                                                                                                                                                                         7
# Percent__COMMUTING_TO_WORK__Car_truck_or_van__carpooled                                                                                                                                                                                           7
# Percent__OCCUPATION__Production_transportation_and_material_moving_occupations                                                                                                                                                                    7
# Percent__PERCENTAGE_OF_FAMILIES_AND_PEOPLE_WHOSE_INCOME_IN_THE_PAST_12_MONTHS_IS_BELOW_THE_POVERTY_LEVEL__Families_with_female_householder_no_husband_present__With_related_children_under_18_years__With_related_children_under_5_years_only     7
# Percent__OCCUPATION__Natural_resources_construction_and_maintenance_occupations                                                                                                                                                                   7
# Percent__OCCUPATION__Sales_and_office_occupations                                                                                                                                                                                                 7
# Percent__OCCUPATION__Service_occupations                                                                                                                                                                                                          7
# Percent__OCCUPATION__Management_business_science_and_arts_occupations                                                                                                                                                                             7
# Percent__COMMUTING_TO_WORK__Worked_at_home                                                                                                                                                                                                        7
# dtype: int64
#
# 2015 0
# Estimate__INCOME_AND_BENEFITS_IN__INFLATIONADJUSTED_DOLLARS__With_cash_public_assistance_income__Mean_cash_public_assistance_income_dollars                                                                                                                                            50
# Percent__COMMUTING_TO_WORK__Car_truck_or_van__drove_alone                                                                                                                                                                                                                               9
# Percent__COMMUTING_TO_WORK__Worked_at_home                                                                                                                                                                                                                                              9
# Percent__COMMUTING_TO_WORK__Other_means                                                                                                                                                                                                                                                 9
# Percent__COMMUTING_TO_WORK__Walked                                                                                                                                                                                                                                                      9
# Percent__COMMUTING_TO_WORK__Public_transportation_excluding_taxicab                                                                                                                                                                                                                     9
# Percent__COMMUTING_TO_WORK__Car_truck_or_van__carpooled                                                                                                                                                                                                                                 9
# Percent__PERCENTAGE_OF_FAMILIES_AND_PEOPLE_WHOSE_INCOME_IN_THE_PAST_12_MONTHS_IS_BELOW_THE_POVERTY_LEVEL__Families_with_female_householder_no_husband_present__With_related_children_of_the_householder_under_18_years__With_related_children_of_the_householder_under_5_years_only     6
# Percent__EMPLOYMENT_STATUS__Females_16_years_and_over__In_labor_force__Civilian_labor_force                                                                                                                                                                                             5
# Percent__EMPLOYMENT_STATUS__Females_16_years_and_over__In_labor_force__Civilian_labor_force__Employed                                                                                                                                                                                   5
# dtype: int64
#
# 2016 0
# Estimate__INCOME_AND_BENEFITS_IN__INFLATIONADJUSTED_DOLLARS__With_cash_public_assistance_income__Mean_cash_public_assistance_income_dollars    83
# Percent__OCCUPATION__Production_transportation_and_material_moving_occupations                                                                 10
# Percent__OCCUPATION__Natural_resources_construction_and_maintenance_occupations                                                                10
# Percent__OCCUPATION__Sales_and_office_occupations                                                                                              10
# Percent__OCCUPATION__Service_occupations                                                                                                       10
# Percent__OCCUPATION__Management_business_science_and_arts_occupations                                                                          10
# Percent__COMMUTING_TO_WORK__Car_truck_or_van__drove_alone                                                                                       9
# Percent__COMMUTING_TO_WORK__Car_truck_or_van__carpooled                                                                                         9
# Percent__COMMUTING_TO_WORK__Worked_at_home                                                                                                      9
# Percent__COMMUTING_TO_WORK__Other_means                                                                                                         9
# dtype: int64
#
# 2010 0
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea                                   651
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Europe                                                                                    651
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Northern_America                                                                          651
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Latin_America                                                                             651
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Africa                                                                                    651
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Asia                                                                                      651
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Oceania                                                                                   651
# Percent__LANGUAGE_SPOKEN_AT_HOME__English_only                                                                                            438
# Percent__LANGUAGE_SPOKEN_AT_HOME__Language_other_than_English                                                                             438
# Percent__LANGUAGE_SPOKEN_AT_HOME__Language_other_than_English__Asian_and_Pacific_Islander_languages__Speak_English_less_than_very_well    438
# dtype: int64
#
# 2011 0
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea                                   665
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Europe                                                                                    665
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Northern_America                                                                          665
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Latin_America                                                                             665
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Africa                                                                                    665
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Asia                                                                                      665
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Oceania                                                                                   665
# Percent__LANGUAGE_SPOKEN_AT_HOME__English_only                                                                                            451
# Percent__LANGUAGE_SPOKEN_AT_HOME__Language_other_than_English                                                                             451
# Percent__LANGUAGE_SPOKEN_AT_HOME__Language_other_than_English__Asian_and_Pacific_Islander_languages__Speak_English_less_than_very_well    451
# dtype: int64
#
# 2012 0
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Africa                                                       650
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Latin_America                                                650
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Northern_America                                             650
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Asia                                                         650
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Europe                                                       650
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea      650
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Oceania                                                      650
# Percent__LANGUAGE_SPOKEN_AT_HOME__Language_other_than_English__Spanish                                       412
# Percent__LANGUAGE_SPOKEN_AT_HOME__Language_other_than_English__Spanish__Speak_English_less_than_very_well    412
# Percent__LANGUAGE_SPOKEN_AT_HOME__Language_other_than_English                                                412
# dtype: int64
#
# 2013 0
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea                                   656
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Europe                           656
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Northern_America                 656
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Latin_America                    656
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Africa                           656
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Asia                             656
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Oceania                          656
# Percent__LANGUAGE_SPOKEN_AT_HOME__Population_5_years_and_over__English_only                                                               428
# Percent__LANGUAGE_SPOKEN_AT_HOME__Population_5_years_and_over__Language_other_than_English                                                428
# Percent__LANGUAGE_SPOKEN_AT_HOME__Population_5_years_and_over__Asian_and_Pacific_Islander_languages__Speak_English_less_than_very_well    428
# dtype: int64
#
# 2014 0
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea                      649
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Europe              649
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Northern_America    649
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Latin_America       649
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Oceania             649
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Africa              649
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Asia                649
# Percent__LANGUAGE_SPOKEN_AT_HOME__Population_5_years_and_over__Other_languages__Speak_English_less_than_very_well            434
# Percent__LANGUAGE_SPOKEN_AT_HOME__Population_5_years_and_over__Spanish                                                       434
# Percent__LANGUAGE_SPOKEN_AT_HOME__Population_5_years_and_over__Spanish__Speak_English_less_than_very_well                    434
# dtype: int64
#
# 2015 0
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea                      651
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Europe              651
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Northern_America    651
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Latin_America       651
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Oceania             651
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Africa              651
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Asia                651
# Percent__LANGUAGE_SPOKEN_AT_HOME__Population_5_years_and_over__Other_languages__Speak_English_less_than_very_well            420
# Percent__LANGUAGE_SPOKEN_AT_HOME__Population_5_years_and_over__Spanish                                                       420
# Percent__LANGUAGE_SPOKEN_AT_HOME__Population_5_years_and_over__Spanish__Speak_English_less_than_very_well                    420
# dtype: int64
#
# 2016 0
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea                      658
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Europe              658
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Northern_America    658
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Latin_America       658
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Oceania             658
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Africa              658
# Percent__WORLD_REGION_OF_BIRTH_OF_FOREIGN_BORN__Foreignborn_population_excluding_population_born_at_sea__Asia                658
# Percent__LANGUAGE_SPOKEN_AT_HOME__Population_5_years_and_over__Other_languages__Speak_English_less_than_very_well            425
# Percent__LANGUAGE_SPOKEN_AT_HOME__Population_5_years_and_over__Spanish                                                       425
# Percent__LANGUAGE_SPOKEN_AT_HOME__Population_5_years_and_over__Spanish__Speak_English_less_than_very_well                    425
# dtype: int64
#
# 2011 0
# Year                                                                                                                       0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Net Migration - Domestic                  0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Net Migration - International [2]         0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Net Migration - Total                     0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Vital Events - Deaths                     0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Vital Events - Births                     0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Natural Increase                          0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Total Population Change [1]               0
# Cumulative Estimates of the Components of Population Change - April 1,  to July 1,  - Net Migration - Domestic             0
# Cumulative Estimates of the Components of Population Change - April 1,  to July 1,  - Net Migration - International [2]    0
# dtype: int64
#
# 2012 0
# Year                                                                                                                       0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Net Migration - Domestic                  0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Net Migration - International [2]         0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Net Migration - Total                     0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Vital Events - Deaths                     0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Vital Events - Births                     0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Natural Increase                          0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Total Population Change [1]               0
# Cumulative Estimates of the Components of Population Change - April 1,  to July 1,  - Net Migration - Domestic             0
# Cumulative Estimates of the Components of Population Change - April 1,  to July 1,  - Net Migration - International [2]    0
# dtype: int64
#
# 2013 0
# Year                                                                                                                       0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Net Migration - Domestic                  0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Net Migration - International [2]         0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Net Migration - Total                     0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Vital Events - Deaths                     0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Vital Events - Births                     0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Natural Increase                          0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Total Population Change [1]               0
# Cumulative Estimates of the Components of Population Change - April 1,  to July 1,  - Net Migration - Domestic             0
# Cumulative Estimates of the Components of Population Change - April 1,  to July 1,  - Net Migration - International [2]    0
# dtype: int64
#
# 2014 0
# Year                                                                                                                       0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Net Migration - Domestic                  0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Net Migration - International [2]         0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Net Migration - Total                     0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Vital Events - Deaths                     0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Vital Events - Births                     0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Natural Increase                          0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Total Population Change [1]               0
# Cumulative Estimates of the Components of Population Change - April 1,  to July 1,  - Net Migration - Domestic             0
# Cumulative Estimates of the Components of Population Change - April 1,  to July 1,  - Net Migration - International [2]    0
# dtype: int64
#
# 2015 0
# Year                                                                                                                       0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Net Migration - Domestic                  0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Net Migration - International [2]         0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Net Migration - Total                     0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Vital Events - Deaths                     0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Vital Events - Births                     0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Natural Increase                          0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Total Population Change [1]               0
# Cumulative Estimates of the Components of Population Change - April 1,  to July 1,  - Net Migration - Domestic             0
# Cumulative Estimates of the Components of Population Change - April 1,  to July 1,  - Net Migration - International [2]    0
# dtype: int64
#
# 2016 0
# Year                                                                                                                       0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Net Migration - Domestic                  0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Net Migration - International [2]         0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Net Migration - Total                     0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Vital Events - Deaths                     0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Vital Events - Births                     0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Natural Increase                          0
# Annual Estimates of the Components of Population Change - July 1,  to July 1,  - Total Population Change [1]               0
# Cumulative Estimates of the Components of Population Change - April 1,  to July 1,  - Net Migration - Domestic             0
# Cumulative Estimates of the Components of Population Change - April 1,  to July 1,  - Net Migration - International [2]    0
# dtype: int64
#
# 2010 0
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Cherokee_tribal_grouping           780
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Chippewa_tribal_grouping           780
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Navajo_tribal_grouping             780
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Sioux_tribal_grouping              780
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Other_Pacific_Islander    778
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Native_Hawaiian           778
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Guamanian_or_Chamorro     778
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Samoan                    778
# Percent__RACE__Native_Hawaiian_and_Other_Pacific_Islander                                      567
# Percent__RACE__One_race__Asian__Asian_Indian                                                   486
# dtype: int64
#
# 2011 0
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Other_Pacific_Islander    790
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Native_Hawaiian           790
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Guamanian_or_Chamorro     790
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Samoan                    790
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Cherokee_tribal_grouping           778
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Chippewa_tribal_grouping           778
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Navajo_tribal_grouping             778
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Sioux_tribal_grouping              778
# Percent__RACE__Native_Hawaiian_and_Other_Pacific_Islander                                      550
# Percent__RACE__One_race__Asian__Asian_Indian                                                   497
# dtype: int64
#
# 2012 0
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Other_Pacific_Islander    785
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Native_Hawaiian           785
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Guamanian_or_Chamorro     785
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Samoan                    785
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Cherokee_tribal_grouping           781
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Chippewa_tribal_grouping           781
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Navajo_tribal_grouping             781
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Sioux_tribal_grouping              781
# Percent__RACE__Native_Hawaiian_and_Other_Pacific_Islander                                      531
# Percent__RACE__One_race__Asian__Asian_Indian                                                   476
# dtype: int64
#
# 2013 0
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Samoan                    787
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Native_Hawaiian           787
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Guamanian_or_Chamorro     787
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Other_Pacific_Islander    787
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Cherokee_tribal_grouping           784
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Chippewa_tribal_grouping           784
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Navajo_tribal_grouping             784
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Sioux_tribal_grouping              784
# Percent__RACE__Native_Hawaiian_and_Other_Pacific_Islander                                      522
# Percent__RACE__One_race__Asian__Asian_Indian                                                   495
# dtype: int64
#
# 2014 0
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Cherokee_tribal_grouping           781
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Chippewa_tribal_grouping           781
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Navajo_tribal_grouping             781
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Sioux_tribal_grouping              781
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Other_Pacific_Islander    780
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Native_Hawaiian           780
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Guamanian_or_Chamorro     780
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Samoan                    780
# Percent__RACE__Native_Hawaiian_and_Other_Pacific_Islander                                      526
# Percent__RACE__One_race__Asian__Asian_Indian                                                   493
# dtype: int64
#
# 2015 0
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Guamanian_or_Chamorro     787
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Other_Pacific_Islander    787
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Samoan                    787
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Native_Hawaiian           787
# Percent__RACE__Native_Hawaiian_and_Other_Pacific_Islander                                      519
# Percent__RACE__One_race__Asian__Other_Asian                                                    466
# Percent__RACE__One_race__Asian__Korean                                                         466
# Percent__RACE__One_race__Asian__Vietnamese                                                     466
# Percent__RACE__One_race__Asian__Japanese                                                       466
# Percent__RACE__One_race__Asian__Filipino                                                       466
# dtype: int64
#
# 2016 0
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Cherokee_tribal_grouping           789
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Chippewa_tribal_grouping           789
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Navajo_tribal_grouping             789
# Percent__RACE__One_race__American_Indian_and_Alaska_Native__Sioux_tribal_grouping              789
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Other_Pacific_Islander    785
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Samoan                    785
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Guamanian_or_Chamorro     785
# Percent__RACE__One_race__Native_Hawaiian_and_Other_Pacific_Islander__Native_Hawaiian           785
# Percent__RACE__Native_Hawaiian_and_Other_Pacific_Islander                                      498
# Percent__RACE__One_race__Asian__Vietnamese                                                     480
# dtype: int64
#
# 2010 0
# Percent__HOUSE_HEATING_FUEL__No_fuel_used              177
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units    177
# Percent__HOUSE_HEATING_FUEL__Utility_gas               177
# Percent__HOUSE_HEATING_FUEL__Bottled_tank_or_LP_gas    177
# Percent__HOUSE_HEATING_FUEL__Electricity               177
# Percent__HOUSE_HEATING_FUEL__Fuel_oil_kerosene_etc     177
# Percent__HOUSE_HEATING_FUEL__Coal_or_coke              177
# Percent__HOUSE_HEATING_FUEL__Wood                      177
# Percent__HOUSE_HEATING_FUEL__Solar_energy              177
# Percent__HOUSE_HEATING_FUEL__Other_fuel                177
# dtype: int64
#
# 2011 0
# Percent__HOUSE_HEATING_FUEL__No_fuel_used              200
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units    200
# Percent__HOUSE_HEATING_FUEL__Utility_gas               200
# Percent__HOUSE_HEATING_FUEL__Bottled_tank_or_LP_gas    200
# Percent__HOUSE_HEATING_FUEL__Electricity               200
# Percent__HOUSE_HEATING_FUEL__Fuel_oil_kerosene_etc     200
# Percent__HOUSE_HEATING_FUEL__Coal_or_coke              200
# Percent__HOUSE_HEATING_FUEL__Wood                      200
# Percent__HOUSE_HEATING_FUEL__Solar_energy              200
# Percent__HOUSE_HEATING_FUEL__Other_fuel                200
# dtype: int64
#
# 2012 0
# Percent__HOUSE_HEATING_FUEL__No_fuel_used              160
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units    160
# Percent__HOUSE_HEATING_FUEL__Utility_gas               160
# Percent__HOUSE_HEATING_FUEL__Bottled_tank_or_LP_gas    160
# Percent__HOUSE_HEATING_FUEL__Electricity               160
# Percent__HOUSE_HEATING_FUEL__Fuel_oil_kerosene_etc     160
# Percent__HOUSE_HEATING_FUEL__Coal_or_coke              160
# Percent__HOUSE_HEATING_FUEL__Wood                      160
# Percent__HOUSE_HEATING_FUEL__Solar_energy              160
# Percent__HOUSE_HEATING_FUEL__Other_fuel                160
# dtype: int64
#
# 2013 0
# Percent__OCCUPANTS_PER_ROOM__Occupied_housing_units__151_or_more     220
# Percent__OCCUPANTS_PER_ROOM__Occupied_housing_units__101_to_150      220
# Percent__OCCUPANTS_PER_ROOM__Occupied_housing_units__100_or_less     220
# Percent__OCCUPANTS_PER_ROOM__Occupied_housing_units                  220
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Electricity     165
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__No_fuel_used    165
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Other_fuel      165
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Solar_energy    165
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Wood            165
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Coal_or_coke    165
# dtype: int64
#
# 2014 0
# Percent__OCCUPANTS_PER_ROOM__Occupied_housing_units__100_or_less               185
# Percent__OCCUPANTS_PER_ROOM__Occupied_housing_units__151_or_more               185
# Percent__OCCUPANTS_PER_ROOM__Occupied_housing_units                            185
# Percent__OCCUPANTS_PER_ROOM__Occupied_housing_units__101_to_150                185
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Coal_or_coke              146
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units                            146
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Utility_gas               146
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Bottled_tank_or_LP_gas    146
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Electricity               146
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Fuel_oil_kerosene_etc     146
# dtype: int64
#
# 2015 0
# Percent__OCCUPANTS_PER_ROOM__Occupied_housing_units__101_to_150               214
# Percent__OCCUPANTS_PER_ROOM__Occupied_housing_units__100_or_less              214
# Percent__OCCUPANTS_PER_ROOM__Occupied_housing_units                           214
# Percent__OCCUPANTS_PER_ROOM__Occupied_housing_units__151_or_more              214
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Coal_or_coke             163
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__No_fuel_used             163
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Other_fuel               163
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Solar_energy             163
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Wood                     163
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Fuel_oil_kerosene_etc    163
# dtype: int64
#
# 2016 0
# Percent__OCCUPANTS_PER_ROOM__Occupied_housing_units__101_to_150                197
# Percent__OCCUPANTS_PER_ROOM__Occupied_housing_units__100_or_less               197
# Percent__OCCUPANTS_PER_ROOM__Occupied_housing_units                            197
# Percent__OCCUPANTS_PER_ROOM__Occupied_housing_units__151_or_more               197
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Wood                      178
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units                            178
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Utility_gas               178
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Bottled_tank_or_LP_gas    178
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Electricity               178
# Percent__HOUSE_HEATING_FUEL__Occupied_housing_units__Fuel_oil_kerosene_etc     178
# dtype: int64

# %% [markdown]
# The migration dataset has missing many values because it has so many more counites than the demographic data that was used to calculate percents. For the census data, it makes sense to drop the columns that have more than 40% of the data missing, and to impute the missing values for the columns that are less than 40% NaN.

# %%
for d in [econ, soc, dem, hous]:
    for yr in d.keys():
        drp_col = []
        for i in d[yr].columns:
            if d[yr][i].isnull().sum() / len(d[yr]) > .4:
                drp_col.append(i)
        d[yr].drop(drp_col, axis=1, inplace=True)
        print (yr, 'columns dropped: ', len(drp_col))
        #d[yr] = KNN(k=3).complete(d[yr])
        #d[yr] = pd.DataFrame(d[yr])
# Out:
# 2010 columns dropped:  0
# 2011 columns dropped:  0
# 2012 columns dropped:  0
# 2013 columns dropped:  0
# 2014 columns dropped:  0
# 2015 columns dropped:  0
# 2016 columns dropped:  0
# 2010 columns dropped:  26
# 2011 columns dropped:  26
# 2012 columns dropped:  19
# 2013 columns dropped:  26
# 2014 columns dropped:  22
# 2015 columns dropped:  22
# 2016 columns dropped:  22
# 2010 columns dropped:  20
# 2011 columns dropped:  20
# 2012 columns dropped:  20
# 2013 columns dropped:  20
# 2014 columns dropped:  20
# 2015 columns dropped:  16
# 2016 columns dropped:  20
# 2010 columns dropped:  0
# 2011 columns dropped:  0
# 2012 columns dropped:  0
# 2013 columns dropped:  0
# 2014 columns dropped:  0
# 2015 columns dropped:  0
# 2016 columns dropped:  0

# %%
for d in [econ, soc, dem, hous]:
    for yr in d.keys():
        col_names = d[yr].columns
        print (yr, d[yr].isnull().sum().sum())
        d[yr] = KNN(k=3).complete(d[yr])
        d[yr] = pd.DataFrame(d[yr])
        d[yr].columns = col_names
# Out:
# 2010 135
# Imputing row 1/807 with 0 missing, elapsed time: 0.346
# Imputing row 101/807 with 0 missing, elapsed time: 0.349
# Imputing row 201/807 with 0 missing, elapsed time: 0.349
# Imputing row 301/807 with 0 missing, elapsed time: 0.350
# Imputing row 401/807 with 0 missing, elapsed time: 0.351
# Imputing row 501/807 with 0 missing, elapsed time: 0.351
# Imputing row 601/807 with 0 missing, elapsed time: 0.352
# Imputing row 701/807 with 0 missing, elapsed time: 0.353
# Imputing row 801/807 with 0 missing, elapsed time: 0.354
# 2011 410
# Imputing row 1/811 with 0 missing, elapsed time: 0.338
# Imputing row 101/811 with 0 missing, elapsed time: 0.339
# Imputing row 201/811 with 0 missing, elapsed time: 0.342
# Imputing row 301/811 with 0 missing, elapsed time: 0.343
# Imputing row 401/811 with 0 missing, elapsed time: 0.345
# Imputing row 501/811 with 0 missing, elapsed time: 0.346
# Imputing row 601/811 with 0 missing, elapsed time: 0.346
# Imputing row 701/811 with 6 missing, elapsed time: 0.349
# Imputing row 801/811 with 0 missing, elapsed time: 0.350
# 2012 175
# Imputing row 1/814 with 0 missing, elapsed time: 0.350
# Imputing row 101/814 with 0 missing, elapsed time: 0.351
# Imputing row 201/814 with 0 missing, elapsed time: 0.352
# Imputing row 301/814 with 0 missing, elapsed time: 0.353
# Imputing row 401/814 with 0 missing, elapsed time: 0.354
# Imputing row 501/814 with 1 missing, elapsed time: 0.354
# Imputing row 601/814 with 0 missing, elapsed time: 0.355
# Imputing row 701/814 with 0 missing, elapsed time: 0.356
# Imputing row 801/814 with 0 missing, elapsed time: 0.357
# 2013 222
# Imputing row 1/817 with 0 missing, elapsed time: 0.429
# Imputing row 101/817 with 0 missing, elapsed time: 0.430
# Imputing row 201/817 with 0 missing, elapsed time: 0.432
# Imputing row 301/817 with 0 missing, elapsed time: 0.433
# Imputing row 401/817 with 0 missing, elapsed time: 0.434
# Imputing row 501/817 with 0 missing, elapsed time: 0.435
# Imputing row 601/817 with 0 missing, elapsed time: 0.435
# Imputing row 701/817 with 1 missing, elapsed time: 0.436
# Imputing row 801/817 with 0 missing, elapsed time: 0.437
# 2014 209
# Imputing row 1/817 with 0 missing, elapsed time: 0.368
# Imputing row 101/817 with 0 missing, elapsed time: 0.369
# Imputing row 201/817 with 0 missing, elapsed time: 0.371
# Imputing row 301/817 with 0 missing, elapsed time: 0.372
# Imputing row 401/817 with 0 missing, elapsed time: 0.372
# Imputing row 501/817 with 0 missing, elapsed time: 0.373
# Imputing row 601/817 with 0 missing, elapsed time: 0.374
# Imputing row 701/817 with 0 missing, elapsed time: 0.374
# Imputing row 801/817 with 0 missing, elapsed time: 0.376
# 2015 214
# Imputing row 1/819 with 0 missing, elapsed time: 0.383
# Imputing row 101/819 with 0 missing, elapsed time: 0.384
# Imputing row 201/819 with 0 missing, elapsed time: 0.386
# Imputing row 301/819 with 0 missing, elapsed time: 0.387
# Imputing row 401/819 with 0 missing, elapsed time: 0.387
# Imputing row 501/819 with 0 missing, elapsed time: 0.388
# Imputing row 601/819 with 0 missing, elapsed time: 0.389
# Imputing row 701/819 with 1 missing, elapsed time: 0.389
# Imputing row 801/819 with 0 missing, elapsed time: 0.391
# 2016 322
# Imputing row 1/820 with 0 missing, elapsed time: 0.424
# Imputing row 101/820 with 0 missing, elapsed time: 0.425
# Imputing row 201/820 with 0 missing, elapsed time: 0.427
# Imputing row 301/820 with 0 missing, elapsed time: 0.428
# Imputing row 401/820 with 0 missing, elapsed time: 0.429
# Imputing row 501/820 with 0 missing, elapsed time: 0.429
# Imputing row 601/820 with 0 missing, elapsed time: 0.430
# Imputing row 701/820 with 0 missing, elapsed time: 0.431
# Imputing row 801/820 with 0 missing, elapsed time: 0.433
# 2010 3384
# Imputing row 1/807 with 0 missing, elapsed time: 0.331
# Imputing row 101/807 with 0 missing, elapsed time: 0.339
# Imputing row 201/807 with 0 missing, elapsed time: 0.344
# Imputing row 301/807 with 0 missing, elapsed time: 0.352
# Imputing row 401/807 with 2 missing, elapsed time: 0.356
# Imputing row 501/807 with 2 missing, elapsed time: 0.360
# Imputing row 601/807 with 1 missing, elapsed time: 0.366
# Imputing row 701/807 with 28 missing, elapsed time: 0.374
# Imputing row 801/807 with 0 missing, elapsed time: 0.379
# 2011 3320
# Imputing row 1/811 with 0 missing, elapsed time: 0.369
# Imputing row 101/811 with 0 missing, elapsed time: 0.377
# Imputing row 201/811 with 2 missing, elapsed time: 0.387
# Imputing row 301/811 with 2 missing, elapsed time: 0.395
# Imputing row 401/811 with 0 missing, elapsed time: 0.403
# Imputing row 501/811 with 1 missing, elapsed time: 0.409
# Imputing row 601/811 with 0 missing, elapsed time: 0.417
# Imputing row 701/811 with 1 missing, elapsed time: 0.425
# Imputing row 801/811 with 0 missing, elapsed time: 0.431
# 2012 4733
# Imputing row 1/814 with 0 missing, elapsed time: 0.379
# Imputing row 101/814 with 0 missing, elapsed time: 0.387
# Imputing row 201/814 with 0 missing, elapsed time: 0.398
# Imputing row 301/814 with 0 missing, elapsed time: 0.408
# Imputing row 401/814 with 0 missing, elapsed time: 0.417
# Imputing row 501/814 with 5 missing, elapsed time: 0.424
# Imputing row 601/814 with 7 missing, elapsed time: 0.433
# Imputing row 701/814 with 0 missing, elapsed time: 0.442
# Imputing row 801/814 with 7 missing, elapsed time: 0.451
# 2013 3091
# Imputing row 1/817 with 1 missing, elapsed time: 0.402
# Imputing row 101/817 with 0 missing, elapsed time: 0.407
# Imputing row 201/817 with 1 missing, elapsed time: 0.414
# Imputing row 301/817 with 1 missing, elapsed time: 0.423
# Imputing row 401/817 with 0 missing, elapsed time: 0.429
# Imputing row 501/817 with 0 missing, elapsed time: 0.432
# Imputing row 601/817 with 0 missing, elapsed time: 0.440
# Imputing row 701/817 with 28 missing, elapsed time: 0.446
# Imputing row 801/817 with 8 missing, elapsed time: 0.452
# 2014 3317
# Imputing row 1/817 with 0 missing, elapsed time: 0.438
# Imputing row 101/817 with 0 missing, elapsed time: 0.444
# Imputing row 201/817 with 0 missing, elapsed time: 0.451
# Imputing row 301/817 with 1 missing, elapsed time: 0.458
# Imputing row 401/817 with 0 missing, elapsed time: 0.464
# Imputing row 501/817 with 0 missing, elapsed time: 0.467
# Imputing row 601/817 with 0 missing, elapsed time: 0.475
# Imputing row 701/817 with 2 missing, elapsed time: 0.480
# Imputing row 801/817 with 0 missing, elapsed time: 0.486
# 2015 3602
# Imputing row 1/819 with 0 missing, elapsed time: 0.394
# Imputing row 101/819 with 2 missing, elapsed time: 0.400
# Imputing row 201/819 with 0 missing, elapsed time: 0.408
# Imputing row 301/819 with 2 missing, elapsed time: 0.416
# Imputing row 401/819 with 0 missing, elapsed time: 0.422
# Imputing row 501/819 with 0 missing, elapsed time: 0.427
# Imputing row 601/819 with 14 missing, elapsed time: 0.433
# Imputing row 701/819 with 34 missing, elapsed time: 0.440
# Imputing row 801/819 with 0 missing, elapsed time: 0.447
# 2016 3332
# Imputing row 1/820 with 0 missing, elapsed time: 0.459
# Imputing row 101/820 with 1 missing, elapsed time: 0.468
# Imputing row 201/820 with 0 missing, elapsed time: 0.475
# Imputing row 301/820 with 0 missing, elapsed time: 0.484
# Imputing row 401/820 with 2 missing, elapsed time: 0.490
# Imputing row 501/820 with 0 missing, elapsed time: 0.495
# Imputing row 601/820 with 0 missing, elapsed time: 0.503
# Imputing row 701/820 with 0 missing, elapsed time: 0.509
# Imputing row 801/820 with 2 missing, elapsed time: 0.515
# 2010 2132
# Imputing row 1/807 with 0 missing, elapsed time: 0.233
# Imputing row 101/807 with 0 missing, elapsed time: 0.235
# Imputing row 201/807 with 0 missing, elapsed time: 0.238
# Imputing row 301/807 with 0 missing, elapsed time: 0.244
# Imputing row 401/807 with 4 missing, elapsed time: 0.247
# Imputing row 501/807 with 0 missing, elapsed time: 0.250
# Imputing row 601/807 with 0 missing, elapsed time: 0.255
# Imputing row 701/807 with 0 missing, elapsed time: 0.260
# Imputing row 801/807 with 0 missing, elapsed time: 0.264
# 2011 2059
# Imputing row 1/811 with 4 missing, elapsed time: 0.204
# Imputing row 101/811 with 0 missing, elapsed time: 0.208
# Imputing row 201/811 with 5 missing, elapsed time: 0.215
# Imputing row 301/811 with 4 missing, elapsed time: 0.223
# Imputing row 401/811 with 0 missing, elapsed time: 0.230
# Imputing row 501/811 with 4 missing, elapsed time: 0.235
# Imputing row 601/811 with 0 missing, elapsed time: 0.240
# Imputing row 701/811 with 14 missing, elapsed time: 0.248
# Imputing row 801/811 with 0 missing, elapsed time: 0.255
# 2012 1701
# Imputing row 1/814 with 0 missing, elapsed time: 0.294
# Imputing row 101/814 with 0 missing, elapsed time: 0.297
# Imputing row 201/814 with 0 missing, elapsed time: 0.303
# Imputing row 301/814 with 0 missing, elapsed time: 0.311
# Imputing row 401/814 with 0 missing, elapsed time: 0.316
# Imputing row 501/814 with 4 missing, elapsed time: 0.318
# Imputing row 601/814 with 0 missing, elapsed time: 0.327
# Imputing row 701/814 with 0 missing, elapsed time: 0.333
# Imputing row 801/814 with 0 missing, elapsed time: 0.339
# 2013 2094
# Imputing row 1/817 with 4 missing, elapsed time: 0.339
# Imputing row 101/817 with 0 missing, elapsed time: 0.344
# Imputing row 201/817 with 0 missing, elapsed time: 0.349
# Imputing row 301/817 with 0 missing, elapsed time: 0.361
# Imputing row 401/817 with 0 missing, elapsed time: 0.368
# Imputing row 501/817 with 4 missing, elapsed time: 0.373
# Imputing row 601/817 with 0 missing, elapsed time: 0.379
# Imputing row 701/817 with 14 missing, elapsed time: 0.389
# Imputing row 801/817 with 5 missing, elapsed time: 0.394
# 2014 1641
# Imputing row 1/817 with 4 missing, elapsed time: 0.291
# Imputing row 101/817 with 0 missing, elapsed time: 0.296
# Imputing row 201/817 with 4 missing, elapsed time: 0.299
# Imputing row 301/817 with 0 missing, elapsed time: 0.304
# Imputing row 401/817 with 0 missing, elapsed time: 0.307
# Imputing row 501/817 with 0 missing, elapsed time: 0.309
# Imputing row 601/817 with 0 missing, elapsed time: 0.314
# Imputing row 701/817 with 4 missing, elapsed time: 0.318
# Imputing row 801/817 with 13 missing, elapsed time: 0.321
# 2015 1694
# Imputing row 1/819 with 4 missing, elapsed time: 0.310
# Imputing row 101/819 with 0 missing, elapsed time: 0.313
# Imputing row 201/819 with 0 missing, elapsed time: 0.316
# Imputing row 301/819 with 5 missing, elapsed time: 0.320
# Imputing row 401/819 with 0 missing, elapsed time: 0.324
# Imputing row 501/819 with 4 missing, elapsed time: 0.326
# Imputing row 601/819 with 5 missing, elapsed time: 0.330
# Imputing row 701/819 with 22 missing, elapsed time: 0.333
# Imputing row 801/819 with 0 missing, elapsed time: 0.337
# 2016 1721
# Imputing row 1/820 with 0 missing, elapsed time: 0.312
# Imputing row 101/820 with 0 missing, elapsed time: 0.318
# Imputing row 201/820 with 0 missing, elapsed time: 0.323
# Imputing row 301/820 with 0 missing, elapsed time: 0.333
# Imputing row 401/820 with 0 missing, elapsed time: 0.338
# Imputing row 501/820 with 0 missing, elapsed time: 0.340
# Imputing row 601/820 with 0 missing, elapsed time: 0.347
# Imputing row 701/820 with 0 missing, elapsed time: 0.353
# Imputing row 801/820 with 13 missing, elapsed time: 0.358
# 2010 2619
# Imputing row 1/807 with 10 missing, elapsed time: 0.742
# Imputing row 101/807 with 0 missing, elapsed time: 0.750
# Imputing row 201/807 with 0 missing, elapsed time: 0.766
# Imputing row 301/807 with 0 missing, elapsed time: 0.775
# Imputing row 401/807 with 0 missing, elapsed time: 0.782
# Imputing row 501/807 with 0 missing, elapsed time: 0.791
# Imputing row 601/807 with 0 missing, elapsed time: 0.794
# Imputing row 701/807 with 10 missing, elapsed time: 0.805
# Imputing row 801/807 with 0 missing, elapsed time: 0.816
# 2011 3120
# Imputing row 1/811 with 10 missing, elapsed time: 0.453
# Imputing row 101/811 with 0 missing, elapsed time: 0.458
# Imputing row 201/811 with 50 missing, elapsed time: 0.467
# Imputing row 301/811 with 8 missing, elapsed time: 0.474
# Imputing row 401/811 with 0 missing, elapsed time: 0.478
# Imputing row 501/811 with 0 missing, elapsed time: 0.481
# Imputing row 601/811 with 0 missing, elapsed time: 0.484
# Imputing row 701/811 with 27 missing, elapsed time: 0.491
# Imputing row 801/811 with 0 missing, elapsed time: 0.498
# 2012 2273
# Imputing row 1/814 with 10 missing, elapsed time: 0.616
# Imputing row 101/814 with 0 missing, elapsed time: 0.623
# Imputing row 201/814 with 10 missing, elapsed time: 0.639
# Imputing row 301/814 with 0 missing, elapsed time: 0.648
# Imputing row 401/814 with 10 missing, elapsed time: 0.653
# Imputing row 501/814 with 0 missing, elapsed time: 0.657
# Imputing row 601/814 with 0 missing, elapsed time: 0.660
# Imputing row 701/814 with 10 missing, elapsed time: 0.666
# Imputing row 801/814 with 0 missing, elapsed time: 0.677
# 2013 3423
# Imputing row 1/817 with 14 missing, elapsed time: 0.539
# Imputing row 101/817 with 0 missing, elapsed time: 0.547
# Imputing row 201/817 with 10 missing, elapsed time: 0.558
# Imputing row 301/817 with 4 missing, elapsed time: 0.567
# Imputing row 401/817 with 0 missing, elapsed time: 0.573
# Imputing row 501/817 with 0 missing, elapsed time: 0.576
# Imputing row 601/817 with 0 missing, elapsed time: 0.580
# Imputing row 701/817 with 10 missing, elapsed time: 0.587
# Imputing row 801/817 with 4 missing, elapsed time: 0.597
# 2014 3009
# Imputing row 1/817 with 4 missing, elapsed time: 0.484
# Imputing row 101/817 with 0 missing, elapsed time: 0.491
# Imputing row 201/817 with 14 missing, elapsed time: 0.502
# Imputing row 301/817 with 0 missing, elapsed time: 0.512
# Imputing row 401/817 with 0 missing, elapsed time: 0.522
# Imputing row 501/817 with 0 missing, elapsed time: 0.528
# Imputing row 601/817 with 0 missing, elapsed time: 0.535
# Imputing row 701/817 with 0 missing, elapsed time: 0.543
# Imputing row 801/817 with 4 missing, elapsed time: 0.554
# 2015 4339
# Imputing row 1/819 with 8 missing, elapsed time: 0.637
# Imputing row 101/819 with 0 missing, elapsed time: 0.644
# Imputing row 201/819 with 0 missing, elapsed time: 0.659
# Imputing row 301/819 with 29 missing, elapsed time: 0.670
# Imputing row 401/819 with 0 missing, elapsed time: 0.679
# Imputing row 501/819 with 0 missing, elapsed time: 0.688
# Imputing row 601/819 with 12 missing, elapsed time: 0.696
# Imputing row 701/819 with 22 missing, elapsed time: 0.706
# Imputing row 801/819 with 0 missing, elapsed time: 0.726
# 2016 4618
# Imputing row 1/820 with 0 missing, elapsed time: 0.756
# Imputing row 101/820 with 4 missing, elapsed time: 0.766
# Imputing row 201/820 with 0 missing, elapsed time: 0.782
# Imputing row 301/820 with 0 missing, elapsed time: 0.793
# Imputing row 401/820 with 4 missing, elapsed time: 0.804
# Imputing row 501/820 with 0 missing, elapsed time: 0.812
# Imputing row 601/820 with 0 missing, elapsed time: 0.821
# Imputing row 701/820 with 0 missing, elapsed time: 0.830
# Imputing row 801/820 with 0 missing, elapsed time: 0.843

# %%
for d in comm_dicts:
    for yr in d.keys():
        print (yr, 'Columns: ', len(d[yr].columns), 'Rows: ', len(d[yr]), 
               'NaNs: ', d[yr].isnull().sum().sum())
# Out:
# 2010 Columns:  106 Rows:  807 NaNs:  0
# 2011 Columns:  107 Rows:  811 NaNs:  0
# 2012 Columns:  107 Rows:  814 NaNs:  0
# 2013 Columns:  126 Rows:  817 NaNs:  0
# 2014 Columns:  126 Rows:  817 NaNs:  0
# 2015 Columns:  128 Rows:  819 NaNs:  0
# 2016 Columns:  128 Rows:  820 NaNs:  0
# 2010 Columns:  107 Rows:  807 NaNs:  0
# 2011 Columns:  107 Rows:  811 NaNs:  0
# 2012 Columns:  114 Rows:  814 NaNs:  0
# 2013 Columns:  120 Rows:  817 NaNs:  0
# 2014 Columns:  124 Rows:  817 NaNs:  0
# 2015 Columns:  124 Rows:  819 NaNs:  0
# 2016 Columns:  124 Rows:  820 NaNs:  0
# 2011 Columns:  16 Rows:  3143 NaNs:  0
# 2012 Columns:  16 Rows:  3143 NaNs:  0
# 2013 Columns:  16 Rows:  3143 NaNs:  0
# 2014 Columns:  16 Rows:  3142 NaNs:  0
# 2015 Columns:  16 Rows:  3142 NaNs:  0
# 2016 Columns:  16 Rows:  3142 NaNs:  0
# 2010 Columns:  52 Rows:  807 NaNs:  0
# 2011 Columns:  52 Rows:  811 NaNs:  0
# 2012 Columns:  52 Rows:  814 NaNs:  0
# 2013 Columns:  56 Rows:  817 NaNs:  0
# 2014 Columns:  56 Rows:  817 NaNs:  0
# 2015 Columns:  63 Rows:  819 NaNs:  0
# 2016 Columns:  59 Rows:  820 NaNs:  0
# 2010 Columns:  129 Rows:  807 NaNs:  0
# 2011 Columns:  129 Rows:  811 NaNs:  0
# 2012 Columns:  129 Rows:  814 NaNs:  0
# 2013 Columns:  134 Rows:  817 NaNs:  0
# 2014 Columns:  134 Rows:  817 NaNs:  0
# 2015 Columns:  136 Rows:  819 NaNs:  0
# 2016 Columns:  136 Rows:  820 NaNs:  0

# %% [markdown]
# ## Saving the output

# %%
com_dict_keys = ['econ', 'soc', 'migr', 'dem', 'hous']

# %%
census_data = {}
for i in np.arange(len(comm_dicts)):
    census_data[com_dict_keys[i]] = comm_dicts[i]

# %%
output = open('./data/dataframes/CensusData.pkl', 'wb')
pickle.dump(census_data, output)
output.close()
